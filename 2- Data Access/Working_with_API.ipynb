# %% [markdown]
# #**1- What is API?**
#
# An API, or Application Programming Interface, is a server that you can use to retrieve and send data to using code. APIs are most commonly used to retrieve data.
#
# When we want to receive data from an API, we need to make a request. Requests are used all over the web. For instance, when you visited Google colab , your web browser made a request to the Google web server, which responded with the content of this page.
#
# API requests work in exactly the same way – you make a request to an API server for data, and it responds to your request.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**2- Overview of HTTP**
#
# When you, the client, use a web page your browser sends an HTTP request to the server where the page is hosted. The server tries to find the desired resource by default "index.html". If your request is successful, the server will send the object to the client in an HTTP response; this includes information like the type of the resource, the length of the resource, and other information.
#
# The figure below represents the process; the circle on the left represents the client, the circle on the right represents the Web server. The table under the Web server represents a list of resources stored in the web server. In this case an HTML file, png image, and txt file .
#
# The HTTP protocol allows you to send and receive information through the web including webpages, images, and other web resources. In this lab, we will provide an overview of the Requests library for interacting with the HTTP  protocol.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/images/reqest_basics.png" width="750" align="center">
#
# </div>

# %% [markdown]
# **Uniform Resource Locator or URL:**
#
# URL is the most popular way to find resources on the web.
#
# **Request:**
#
# The process can be broken into the request and response process. When an HTTP request is made, an HTTP method is sent, this tells the server what action to perform. A list of several HTTP methods is shown below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Responces:**
#
#
#
#
#
#
# An HTTP response is made by a server to a client. The aim of the response is to provide the client with the resource it requested, or inform the client that the action it requested has been carried out; or else to inform the client that an error occurred in processing its request.
#
# ```
# An HTTP response contains:
# A status line.
# A series of HTTP headers, or header fields.
# A message body, which is usually needed
# ```
#
# Some HTTP responses examples are shown below:
#
#
# **1- General**
# ```
# 400 BAD REQUEST: The request was invalid or cannot be otherwise served. An accompanying error message will explain further. For security reasons, requests without authentication are considered invalid and will yield this response.
#
# 401 UNAUTHORIZED: The authentication credentials are missing, or if supplied are not valid or not sufficient to access the resource.
#
# 403 FORBIDDEN: The request has been refused. See the accompanying message for the specific reason (most likely for exceeding rate limit).
#
# 404 NOT FOUND: The URI requested is invalid or the resource requested does not exists.
#
# 406 NOT ACCEPTABLE: The request specified an invalid format.
#
# 410 GONE: This resource is gone. Used to indicate that an API endpoint has been turned off.
#
# 429 TOO MANY REQUESTS: Returned when a request cannot be served due to the application’s rate limit having been exhausted for the resource.
#
# 500 INTERNAL SERVER ERROR: Something is horribly wrong.
#
# 502 BAD GATEWAY: The service is down or being upgraded. Try again later.
#
# 503 SERVICE UNAVAILABLE: The service is up, but overloaded with requests. Try again later.
#
# 504 GATEWAY TIMEOUT: Servers are up, but the request couldn’t be serviced due to some failure within our stack. Try again later.
# ```
# **2- HTTP GET**
# ```
# 200 OK: The request was successful and the response body contains the representation requested.
#
# 302 FOUND: A common redirect response; you can GET the representation at the URI in the Location response header.
#
# 304 NOT MODIFIED: There is no new data to return.
# ```
# **3- HTTP POST or PUT**
# ```
# 201 OK: The request was successful, we updated the resource and the response body contains the representation.
#
# 202 ACCEPTED: The request has been accepted for further processing, which will be completed sometime later.
# ```
# **4- HTTP DELETE**
# ```
# 202 ACCEPTED: The request has been accepted for further processing, which will be completed sometime later.
#
# 204 OK: The request was successful; the resource was deleted.
# ```

# %% [markdown]
# #**Requests Library in Python**
#
# In order to work with APIs in Python, we need tools that will make those requests. In Python, the most common library for making requests and working with APIs is the requests library. The requests library isn’t part of the standard Python library, so you’ll need to install it to get started

# %% [markdown]
# If you use pip to manage your Python packages, you can install requests using the following command:
#
#
#
# ```
# pip install requests
# ```
#
# If you use conda, the command you’ll need is:
#
#
#
# ```
# conda install requests
#
# ```
# Once you’ve installed the library, you’ll need to import it. Let’s start with that important step:
#
#
#
# ```
# import requests
# ```

# %% [markdown]
# HTTP methods such as GET and POST, determine which action you’re trying to perform when making an HTTP request. Besides GET and POST, there are several other common methods that you’ll use later in this tutorial.
#
# One of the most common HTTP methods is GET. The GET method indicates that you’re trying to get or retrieve data from a specified resource. To make a GET request, invoke:
#
#
# ```
# requests.get()
# ```

# %% [markdown]
# #**1- GitHub**

# %%
#one time!
import requests

# %%
from pprint import pprint
req = requests.get('https://api.github.com')
req.status_code
pprint(req.content)

# %%
#GitHub Data with specific user name, in this example, fabpot
res = requests.get('https://api.github.com/users/fabpot')
data = res.json()
pprint(data)

# %%
# Create an API request 
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
response = requests.get(url)
print("Status code: ", response.status_code)
# In a variable, save the API response.
response_dict = response.json()
# Evaluate the results.
print(response_dict)
# Out:
# Status code:  200
# ...

# %%
#save the json text in .json file
json_object = json.dumps(response_dict, indent = 4)

with open("samplefile.json", "w") as outfile:
    outfile.write(json_object)

# %% [markdown]
# #####**Now let's see how Github API Library in Python works!**
#
# PyGithub is a Python library to use the Github API v3. With it, you can manage your Github resources (repositories, user profiles, organizations, etc.) from Python scripts.

# %%
# pip install PyGithub

# %%
from github import Github

# First create a Github instance:

# using an access token
g = Github("access_token")

#OR

# Github Enterprise with custom hostname
 g = Github(base_url="https://{hostname}/api/v3", login_or_token="access_token")

# Then play with your Github objects:
for repo in g.get_user().get_repos():
    print(repo.name)

# %% [markdown]
# # **2- Kaggle API**

# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
#pip install Kaggle

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
#Download a specif data if you have the name of the dataset
api.dataset_download_files('giantuji/UjiIndoorLoc')

# %%
# !unzip '/content/UjiIndoorLoc.zip'
# Out:
# Archive:  /content/UjiIndoorLoc.zip
#   inflating: TrainingData.csv
#   inflating: ValidationData.csv

# %%
# Another Dataset
api.dataset_download_files('yamqwe/omicron-covid19-variant-daily-cases')

# %%
#Search for datasets which are spatial
# !kaggle datasets list -s 'spatial'

# %%
# !kaggle datasets download -d shrishailgajbhar/flipkart-headphones-dataset

# %%
#All datasets related to health competition
# !kaggle competitions list -s health
# Out:
# ...
# ref                                                  deadline             category       reward  teamCount  userHasEntered
# ---------------------------------------------------  -------------------  ----------  ---------  ---------  --------------
# hhp                                                  2013-04-04 07:00:00  Featured     $500,000       1350           False
# nfl-health-and-safety-helmet-assignment              2021-11-02 23:59:00  Featured     $100,000        825           False
# datasciencebowl                                      2015-03-16 23:59:00  Featured     $175,000       1049           False
# stanford-covid-vaccine                               2020-10-06 23:59:00  Research      $25,000       1636           False
# hubmap-kidney-segmentation                           2021-05-10 23:59:00  Research      $60,000       1200           False
# osic-pulmonary-fibrosis-progression                  2020-10-06 23:59:00  Featured      $55,000       2097           False
# ...

# %% [markdown]
# #**3- Chicago Taxi Dataset**
#
# Taxi trips reported to the City of Chicago in its role as a regulatory agency. To protect privacy but allow for aggregate analyses, the Taxi ID is consistent for any given taxi medallion number but does not show the number, Census Tracts are suppressed in some cases, and times are rounded to the nearest 15 minutes.
# You can find this dataset here: https://data.cityofchicago.org/Transportation/Taxi-Trips/wrvz-psew

# %%
import requests
address = "https://data.cityofchicago.org/resource/wrvz-psew.json"
req = requests.get(address)

# %%
print(req.status_code)
# Out:
# 200

# %%
data = req.json()
print(data)
# Out:
# [{'trip_id': '54d812a0b88f8f9707825261014b3563a0a60ace', 'taxi_id': 'f98ae5e71fdda8806710af321dce58002146886c013f411be2cd336e0c224e78ed85626eeee462f0d1f5e6b29a030514b95f7b1b8ca59888a10b52dfe55ddf99', 'trip_start_timestamp': '2022-01-01T00:00:00.000', 'trip_end_timestamp': '2022-01-01T00:00:00.000', 'trip_seconds': '536', 'trip_miles': '4.83', 'pickup_community_area': '28', 'dropoff_community_area': '22', 'fare': '14.75', 'tips': '0', 'tolls': '0', 'extras': '0', 'trip_total': '14.75', 'payment_type': 'Cash', 'company': 'Globe Taxi', 'pickup_centroid_latitude': '41.874005383', 'pickup_centroid_longitude': '-87.66351755', 'pickup_centroid_location': {'type': 'Point', 'coordinates': [-87.6635175498, 41.874005383]}, 'dropoff_centroid_latitude': '41.92276062', 'dropoff_centroid_longitude': '-87.699155343', 'dropoff_centroid_location': {'type': 'Point', 'coordinates': [-87.6991553432, 41.9227606205]}, ':@computed_region_vrxf_vc4k': '29'}, {'trip_id': 'c7d7652d874913e64a674c49598bf6e5b659d9
# ...

# %%
data[1]
# Out:
# {':@computed_region_vrxf_vc4k': '23',
#  'company': 'Taxi Affiliation Services',
#  'dropoff_centroid_latitude': '41.92276062',
#  'dropoff_centroid_location': {'coordinates': [-87.6991553432, 41.9227606205],
#   'type': 'Point'},
#  'dropoff_centroid_longitude': '-87.699155343',
#  'dropoff_community_area': '22',
#  'extras': '0',
#  'fare': '3.25',
#  'payment_type': 'Cash',
#  'pickup_centroid_latitude': '41.92276062',
#  'pickup_centroid_location': {'coordinates': [-87.6991553432, 41.9227606205],
#   'type': 'Point'},
#  'pickup_centroid_longitude': '-87.699155343',
#  'pickup_community_area': '22',
#  'taxi_id': 'f32c0c8e63d4e5d4bfc7e9d57e5d0f6dcf28450850245d82d729dde7eb92a44d41187faf585ecd05b40eb253cdd48e9a1cfcb9bda17c6bc1df087f068afc144c',
#  'tips': '0',
#  'tolls': '0',
#  'trip_end_timestamp': '2022-01-01T00:00:00.000',
#  'trip_id': 'c7d7652d874913e64a674c49598bf6e5b659d9c1',
#  'trip_miles': '0',
#  'trip_seconds': '0',
# ...

# %%
  d = req.text
  file1 = open("MyFile.txt","a")
  file1.write(d)
  file1.close()

# %%
for i in range(10):
  address = 'https://data.cityofchicago.org/resource/wrvz-psew.json?trip_id=00000023035db9c57ce41840d9b350ada2041145'
  # address = 'https://data.cityofchicago.org/resource/wrvz-psew.csv?trip_seconds=1200&$limit=2000&$offset='+str(i*20)+"$app_token=L9LuSaRDkN9ckAxIiuSzQ0pVY'
  res = requests.get(address)

  d = res.text
  file1 = open("MyFile.csv","a")
  file1.write(d)
  file1.close()

print(d)

# %%
import requests
qry = 'select count(trip_seconds) where trip_seconds>1200 and trip_seconds<1300 limit 100'
address = 'https://data.cityofchicago.org/resource/wrvz-psew.json?$query='+qry+'&$$app_token=6ay0688fsi3k3z2my6it0gtqxcqy8sp0rvkqra447zglnq0knx'
res = requests.get(address)

d = res.json()

print(d)
# Out:
# {'code': 'permission_denied', 'error': True, 'message': 'Invalid app_token specified'}

# %% [markdown]
# Another way to access this dataset is through `Sodapy` library:
# For this dataset, you can use **SODA API**.
#
# Simple Oracle Document Access (SODA) is a set of NoSQL-style APIs that let you create and store collections of documents (in particular JSON) in Oracle Database, retrieve them, and query them, without needing to know Structured Query Language (SQL) or how the documents are stored in the database.

# %%
# !pip install sodapy

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org/resource/wrvz-psew.json?$query='"+qry+"'", app_token="L9LuSaRDkN9ckAxIiuSzQ0pVY")
# dzktvx6mgf59j27hbg4m79n6e
# Secret: 5f6nmkitfrykw4qstwbdoe6jzr12m58ffbu6r78ijo6ktyhzby

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

client.timeout = 50

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("wrvz-psew","$query=SELECT count(trip_seconds) where trip_seconds>1200 and trip_seconds<1300 limit 100")

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %% [markdown]
# #**Now, Let us see how ***streaming API*** works!**

# %% [markdown]
# #**1- Twitter API**
#
# Assuming that you already have a Twitter account and you are logged in. If you do not have a Twitter account, you have to create a new one. You need to obtain the Twitter Authentication keys in order to get Twitter data.
#
# 1- Go to the developer portal dashboard:https://developer.twitter.com/en/portal/petition/essential/basic-info
#
# 2- Sign in with your account
#
# 3- Create a new project, give it a name, a use-case based on the goal you want to achieve, and a description.
#
# tou can check this link to see what Twiteer oppfers to developers: https://developer.twitter.com/en/docs/twitter-api/tools-and-libraries/v2

# %%
consumer_key = "8tQljZySn3sbMpwAVz8LpuCJJ"
consumer_secret = "bFBOkoKCFeU4VGk3X3Za6lgFDm8d9ag2aqDv1A7aUez50dWfm7"
access_token = "1484319700917964804-Z4pAEMpcCpE05NwEqQkPvACarxkMqj"
access_token_secret = "XMqAO2SJC8glIbqgtVfhQYZr7bG9WJCEdWcmO7ocGva0C"

# %%
#!pip install tweepy
#!pip install pprintpp
import tweepy
import pandas as pd

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
cursor = tweepy.Cursor(api.user_timeline, id='JustinTrudeau', tweet_mode= 'extended').items(10)
print(cursor)

# %%
import pprint
for i in cursor:
  print(i)
# Out:
# Status(_api=<tweepy.api.API object at 0x7fa8ee927610>, _json={'created_at': 'Mon Jan 24 14:01:06 +0000 2022', 'id': 1485613633040175110, 'id_str': '1485613633040175110', 'full_text': 'Today, we celebrate the rich cultures, heritage, and achievements of Africans and African diasporas, and recognize the countless contributions they make in communities from coast to coast to coast. \nhttps://t.co/vkv6XgYPzy', 'truncated': False, 'display_text_range': [0, 222], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/vkv6XgYPzy', 'expanded_url': 'https://pm.gc.ca/en/news/statements/2022/01/24/statement-prime-minister-world-day-african-and-afrodescendant-culture', 'display_url': 'pm.gc.ca/en/news/statem…', 'indices': [199, 222]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply
# ...

# %%
class StreamListener(tweepy.StreamListener):
  def on_status(self, status):
    print(status.text)

# %%
stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["trump", "clinton", "hillary clinton", "donald trump"])

# %%
#public_tweets = api.home_timeline()

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# RT @VitaliteNB: 📣 Vaccination clinics at Old Moncton High School
# ✅January 26, 27, 12:30 p.m. to 7 p.m.
# ✅January 29, 30, 9 a.m. to 4 p.m.…
# An update on schools will be provided at 2:30 p.m. on Monday, January 24.
#
# To watch in English:… https://t.co/7XBJ9JQ2Hg
# RBC is launching Future NB Week for the first time! GNB is a proud partner of this initiative and we encourage you… https://t.co/NAWSfXexPG
# RT @VitaliteNB: 📣 Walk-in vaccination clinic at the Centre des congrès de la Péninsule acadienne, Shippagan TODAY, January 24, 8:30 a.m. to…
# Register for testing here: https://t.co/2kYfvgm7Ig
#
# If you test positive on a rapid point-of-care test (POCT) regis… https://t.co/cTWuBS4JMT
# RT @VitaliteNB: 📢 Walk-in and by appointment vaccination clinics at Old Moncton High School January 24, 25, 28 &amp; 31, 9 a.m. to 4:30 p.m.…
# Our COVID-19 dashboard has been updated. Visit https://t.co/oIqIZSv1av https://t.co/ylhkZKGTBE
# ...
