# %% [markdown]
# #**MongoDB With Python**
#
# MongoDB stores data in JSON-like documents, which makes the database very flexible and scalable.
# To be able to experiment with the code examples in this Notebook, you will need access to a MongoDB database.
# You can download a free MongoDB database at https://www.mongodb.com.
# Or get started right away with a MongoDB cloud service at https://www.mongodb.com/cloud/atlas.

# %% [markdown]
# ##**PyMongo**

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (4.0.1)

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.0.1)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.2.0-py3-none-any.whl (266 kB)
#      |████████████████████████████████| 266 kB 15.5 MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-2.2.0

# %% [markdown]
# ##**1- Create Database**
#
# To create a database in MongoDB, start by creating a MongoClient object, then specify a connection URL with the correct ip address and the name of the database you want to create.
# MongoDB will create the database if it does not exist, and make a connection to it.

# %%
# Create a database called "mydatabase":
import pymongo

myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")

mydb = myclient["mydatabase"]

# %% [markdown]
# ```
# Note:
# In MongoDB, a database is not created until it gets content!
# MongoDB waits until you have created a collection (table), with at least one document (record) before it actually creates the database
# (and collection).
#
#
#
# ```

# %% [markdown]
# ##**2. Check if Database Exists**
#
# Remember:
# In MongoDB, a database is not created until it gets content, so if this is your first time creating a database, you should complete the next two chapters (create collection and create document) before you check if the database exists!
# You can check if a database exist by listing all databases in you system:

# %%
# Return a list of your system's databases:
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local', 'test']

# %%
# Check if "mydatabase" exists:

dblist = myclient.list_database_names()
if "mydatabase" in dblist:
    print("The database exists.")
# Out:
# The database exists.

# %% [markdown]
# ##**3. Create Collection**
#
# * To create a collection in MongoDB, use database object and specify the name of the collection you want to create.
#
# * MongoDB will create the collection if it does not exist

# %%
# Create a collection called "customers":
import pymongo

myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
mydb = myclient["mydatabase"]

mycol = mydb["customers"]

# %% [markdown]
# ##**4.Insert Document**
#
# * A document in MongoDB is the same as a record in SQL databases.
#
# * To insert a record, or document as it is called in MongoDB, into a collection, we use the insert_one() method.
#
# * The first parameter of the insert_one() method is a dictionary containing the name(s) and value(s) of each field in the document you want to insert.

# %%
# Insert a record in the "customers" collection:

mydict = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(mydict)

# %% [markdown]
# ##**5. Return the _id Field**
#
# * The insert_one() method returns a InsertOneResult object, which has a property, inserted_id, that holds the id of the inserted document.
#
# * Insert another record in the "customers" collection, and return the value of the _id field:

# %% [markdown]
# * In the example above no _id field was specified, so MongoDB assigned a unique _id for the record (document).

# %%
mydict = { "name": "Peter", "address": "Lowstreet 27" }

x = mycol.insert_one(mydict)

print(x.inserted_id)
# Out:
# 620123974039d142fbd12c33

# %% [markdown]
# ##**6. Insert Multiple Documents**
# * To insert multiple documents into a collection in MongoDB, we use the insert_many() method.
#
# * If you do not want MongoDB to assign unique ids for you document, you can specify the _id field when you insert the document(s).
#
# * Remember that the values has to be unique. Two documents cannot have the same _id.
#
# * The first parameter of the insert_many() method is a list containing dictionaries with the data you want to insert:

# %%
from pprint import pprint


mylist = [
  { "name": "Amy", "address": "Apple st 652"},
  { "name": "Hannah", "address": "Mountain 21"},
  { "name": "Michael", "address": "Valley 345"},
  { "name": "Sandy", "address": "Ocean blvd 2"},
  { "name": "Betty", "address": "Green Grass 1"},
  { "name": "Richard", "address": "Sky st 331"},
  { "name": "Susan", "address": "One way 98"},
  { "name": "Vicky", "address": "Yellow Garden 2"},
  { "name": "Ben", "address": "Park Lane 38"},
  { "name": "William", "address": "Central st 954"},
  { "name": "Chuck", "address": "Main Road 989"},
  { "name": "Viola", "address": "Sideway 1633"}
]

x = mycol.insert_many(mylist)

#print list of the _id values of the inserted documents:
pprint(x.inserted_ids)
# Out:
# [ObjectId('620123aa4039d142fbd12c34'),
#  ObjectId('620123aa4039d142fbd12c35'),
#  ObjectId('620123aa4039d142fbd12c36'),
#  ObjectId('620123aa4039d142fbd12c37'),
#  ObjectId('620123aa4039d142fbd12c38'),
#  ObjectId('620123aa4039d142fbd12c39'),
#  ObjectId('620123aa4039d142fbd12c3a'),
#  ObjectId('620123aa4039d142fbd12c3b'),
#  ObjectId('620123aa4039d142fbd12c3c'),
#  ObjectId('620123aa4039d142fbd12c3d'),
#  ObjectId('620123aa4039d142fbd12c3e'),
#  ObjectId('620123aa4039d142fbd12c3f')]

# %% [markdown]
# ##**7. Insert Multiple Documents, with Specified IDs**
#
# * If you do not want MongoDB to assign unique ids for you document, you can specify the _id field when you insert the document(s).
#
# * Remember that the values has to be unique. Two documents cannot have the same _id.

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customersa"]

mylist = [
  { "_id": 1, "name": "John", "address": "Highway 37"},
  { "_id": 2, "name": "Peter", "address": "Lowstreet 27"},
  { "_id": 3, "name": "Amy", "address": "Apple st 652"},
  { "_id": 4, "name": "Hannah", "address": "Mountain 21"},
  { "_id": 5, "name": "Michael", "address": "Valley 345"},
  { "_id": 6, "name": "Sandy", "address": "Ocean blvd 2"},
  { "_id": 7, "name": "Betty", "address": "Green Grass 1"},
  { "_id": 8, "name": "Richard", "address": "Sky st 331"},
  { "_id": 9, "name": "Susan", "address": "One way 98"},
  { "_id": 10, "name": "Vicky", "address": "Yellow Garden 2"},
  { "_id": 11, "name": "Ben", "address": "Park Lane 38"},
  { "_id": 12, "name": "William", "address": "Central st 954"},
  { "_id": 13, "name": "Chuck", "address": "Main Road 989"},
  { "_id": 14, "name": "Viola", "address": "Sideway 1633"}
]

x = mycol.insert_many(mylist)

#print list of the _id values of the inserted documents:
print(x.inserted_ids)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-321-266aa345d4b7> in <module>
#      22 ]
#      23
# ---> 24 x = mycol.insert_many(mylist)
#      25
#      26 #print list of the _id values of the inserted documents:
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
#     588         blk.ops = [doc for doc in gen()]
# --> 589         blk.execute(write_concern, session=session)
#     590         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     591
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     446                 self.execute_no_results(sock_info, generator)
#     447         else:
# --> 448             return self.execute_command(generator, write_concern, session)
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pymongo\bulk.py in execute_command(self, generator, write_concern, session)
#     346
#     347         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 348             _raise_bulk_write_error(full_result)
#     349         return full_result
#     350
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pymongo\bulk.py in _raise_bulk_write_error(full_result)
#     131         full_result["writeErrors"].sort(
#     132             key=lambda error: error["index"])
# --> 133     raise BulkWriteError(full_result)
#     134
#     135
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'keyPattern': {'_id': 1}, 'keyValue': {'_id': 1}, 'errmsg': 'E11000 duplicate key error collection: mydatabase.customersa index: _id_ dup key: { _id: 1 }', 'op': {'_id': 1, 'name': 'John', 'address': 'Highway 37'}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %% [markdown]
# ##**8. Find**
#
# * In MongoDB we use the find and findOne methods to find data in a collection.
#
# * Just like the SELECT statement is used to find data in a table in a SQL databases
#
# #####**Find One**
# * To select data from a collection in MongoDB, we can use the find_one() method.
#
# * The find_one() method returns the first occurrence in the selection.

# %%
# Find the first document in the customers collection:

x = mycol.find_one()

print(x)
# Out:
# {'_id': ObjectId('620104994039d142fbd0da63'), 'name': 'John', 'address': 'Highway 37'}

# %% [markdown]
# #####**Find All**
#
# * To select data from a table in MongoDB, we can also use the find() method.
#
# * The find() method returns all occurrences in the selection.
#
# * The first parameter of the find() method is a query object. In this example we use an empty query object, which selects all documents in the collection.
#
# * No parameters in the find() method gives you the same result as SELECT * in SQL.

# %%
# Return all documents in the "customers" collection, and print each document:

for x in mycol.find():
    print(x)
# Out:
# {'_id': 1, 'name': 'John', 'address': 'Highway 37'}
# {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'}
# {'_id': 3, 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': 4, 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': 7, 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}
# {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': 12, 'name': 'William', 'address': 'Central st 954'}
# {'_id': 13, 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}

# %% [markdown]
# #####**Return Only Some Fields**
# * The second parameter of the find() method is an object describing which fields to include in the result.
#
# * This parameter is optional, and if omitted, all fields will be included in the result.

# %%
# Return only the names and addresses, not the _ids:

for x in mycol.find({},{ "_id": 0, "name": 1, "address": 1 }):
    print(x)
# Out:
# {'name': 'John', 'address': 'Highway 37'}
# {'name': 'Peter', 'address': 'Lowstreet 27'}
# {'name': 'Amy', 'address': 'Apple st 652'}
# {'name': 'Hannah', 'address': 'Mountain 21'}
# {'name': 'Michael', 'address': 'Valley 345'}
# {'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'name': 'Betty', 'address': 'Green Grass 1'}
# {'name': 'Richard', 'address': 'Sky st 331'}
# {'name': 'Susan', 'address': 'One way 98'}
# {'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'name': 'Ben', 'address': 'Park Lane 38'}
# {'name': 'William', 'address': 'Central st 954'}
# {'name': 'Chuck', 'address': 'Main Road 989'}
# {'name': 'Viola', 'address': 'Sideway 1633'}

# %% [markdown]
# You are not allowed to specify both 0 and 1 values in the same object (except if one of the fields is the _id field). If you specify a field with the value 0, all other fields get the value 1, and vice versa:

# %%
# This example will exclude "address" from the result:

for x in mycol.find({},{ "address": 0 }):
    print(x)
# Out:
# {'_id': 1, 'name': 'John'}
# {'_id': 2, 'name': 'Peter'}
# {'_id': 3, 'name': 'Amy'}
# {'_id': 4, 'name': 'Hannah'}
# {'_id': 5, 'name': 'Michael'}
# {'_id': 6, 'name': 'Sandy'}
# {'_id': 7, 'name': 'Betty'}
# {'_id': 8, 'name': 'Richard'}
# {'_id': 9, 'name': 'Susan'}
# {'_id': 10, 'name': 'Vicky'}
# {'_id': 11, 'name': 'Ben'}
# {'_id': 12, 'name': 'William'}
# {'_id': 13, 'name': 'Chuck'}
# {'_id': 14, 'name': 'Viola'}

# %% [markdown]
# ##**9. Query**
#
# **9.1. Filter the Result**
#
# * When finding documents in a collection, you can filter the result by using a query object.
#
# * The first argument of the `find()` method is a query object, and is used to limit the search.

# %%
# Find document(s) with the address "Park Lane 38":

myquery = { "address": "Park Lane 38" }

mydoc = mycol.find(myquery)

for x in mydoc:
    print(x)
# Out:
# {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'}

# %% [markdown]
# #####**9.2. Advanced Query**
#
# * To make advanced queries you can use modifiers as values in the query object.
#
# * E.g. to find the documents where the "address" field starts with the letter `"S"` or higher (alphabetically), use the greater than modifier: `{"$gt": "S"}`:

# %%
# Find documents where the address starts with the letter "S" or higher:

myquery = { "address": { "$gt": "S" } }

mydoc = mycol.find(myquery)

for x in mydoc:
    print(x)
# Out:
# {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}

# %% [markdown]
# ##**10. Sort**
#
# **Sort the Result**
#
# * Use the `sort()` method to sort the result in ascending or descending order.
#
# * The `sort()` method takes one parameter for "fieldname" and one parameter for "direction" (ascending is the default direction).

# %%
# Sort the result alphabetically by name:

mydoc = mycol.find().sort("name")

for x in mydoc:
    print(x)
# Out:
# {'_id': 3, 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': 7, 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': 13, 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': 4, 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': 1, 'name': 'John', 'address': 'Highway 37'}
# {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'}
# {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}
# {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': 12, 'name': 'William', 'address': 'Central st 954'}

# %% [markdown]
# **Sort Descending**
#
# * Use the value -1 as the second parameter to sort descending.
#
# * sort("name", 1) #ascending
#
# * sort("name", -1) #descending

# %%
# Sort the result reverse alphabetically by name:

mydoc = mycol.find().sort("name", -1)

for x in mydoc:
    print(x)

# %% [markdown]
# ##**11.Delete Document**
#
# * To delete one document, we use the `delete_one()` method.
#
# * The first parameter of the `delete_one()` method is a query object defining which document to delete.
#
# `Note:` If the query finds more than one document, only the first occurrence is deleted.

# %%
# Delete the document with the address "Mountain 21":

myquery = { "address": "Mountain 21" }

mycol.delete_one(myquery)

# %% [markdown]
# * To delete more than one document, use the delete_many() method.
#
# * The first parameter of the delete_many() method is a query object defining which documents to delete.

# %% [markdown]
# ## **12. Drop Collection**
#
# **Delete Collection:**
# You can delete a table, or collection as it is called in MongoDB, by using the `drop()` method.
#
# * The drop() method returns true if the collection was dropped successfully, and false if the collection does not exist.

# %%
# Delete the "customers" collection:

mycol.drop()

# %% [markdown]
# ##**13. Update**
#
# **Update Collection:**
# You can update a record, or document as it is called in MongoDB, by using the `update_one()` method.
#
# * The first parameter of the `update_one()` method is a query object defining which document to update.
#
# `Note`: If the query finds more than one record, only the first occurrence is updated.
#
# * The second parameter is an object defining the new values of the document.

# %%
# Change the address from "Valley 345" to "Canyon 123":

myquery = { "address": "Valley 345" }
newvalues = { "$set": { "address": "Canyon 123" } }

mycol.update_one(myquery, newvalues)

#print "customers" after the update:
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('620108e04039d142fbd0dab8'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('620108ee4039d142fbd0dab9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('620108ee4039d142fbd0daba'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('620108ee4039d142fbd0dabb'), 'name': 'Michael', 'address': 'Canyon 123'}
# {'_id': ObjectId('620108ee4039d142fbd0dabc'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('620108ee4039d142fbd0dabd'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('620108ee4039d142fbd0dabe'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('620108ee4039d142fbd0dabf'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('620108ee4039d142fbd0dac0'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('620108ee4039d142fbd0dac1'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('620108ee4039d142fbd0dac2'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('620108ee4039d142fbd0dac3'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('620108ee4039d142fbd0dac4'), 'name': 'Viola', 'address': 'Sideway 1633'}

# %% [markdown]
# **Update Many:**
# To update all documents that meets the criteria of the query, use the `update_many()` method.

# %%
# Update all documents where the address starts with the letter "S":

myquery = { "address": { "$regex": "^S" } }
newvalues = { "$set": { "name": "Minnie" } }

x = mycol.update_many(myquery, newvalues)

print(x.modified_count, "documents updated.")

# %% [markdown]
# ##**14. Limit**
#
# **Limit the Result:**
# To limit the result in MongoDB, we use the `limit()` method.
#
# * The `limit()` method takes one parameter, a number defining how many documents to return.
#
# Consider you have a "customers" collection:

# %%
# Limit the result to only return 5 documents:

myresult = mycol.find().limit(5)

#print the result:
for x in myresult:
    print(x)
# Out:
# {'_id': ObjectId('620108e04039d142fbd0dab8'), 'name': 'John', 'address': 'Highway 37'}
# {'_id': ObjectId('620108ee4039d142fbd0dab9'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('620108ee4039d142fbd0daba'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('620108ee4039d142fbd0dabb'), 'name': 'Michael', 'address': 'Canyon 123'}
# {'_id': ObjectId('620108ee4039d142fbd0dabc'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}

# %% [markdown]
# ## **Collect Data with API and store it in MongoDB**

# %% [markdown]
# **1- Game Data**
#  https://www.gamespot.com/api/?

# %%
from pymongo import MongoClient
import requests
import pandas as pd
import pymongo

# %%
# client = MongoClient('127.0.0.1', 27017)
# db_name = 'gamespot_reviews'

# # connect to the database
# db = client['Kaggle']


client = pymongo.MongoClient('mongodb://127.0.0.1:27017/')

# connect to the database
db = client['Games']

reviews = db.gameReviews

# %%
games_base = "http://www.gamespot.com/api/reviews/?api_key=[YOUR KEY]&format=json"
headers = {
    "user_agent": "nasrineshraghi API Access"
}

# %%
review_fields = "id,title,score,deck,body,good,bad"

# %%
pages = list(range(0, 20))
pages_list = pages[0:20:10]

# %%
def get_games(url_base, num_pages, fields, collection):

    field_list = "&field_list=" + fields + "&sort=score:desc" + "&offset="

    for page in num_pages:
        url = url_base + field_list + str(page)
        response = requests.get(url, headers=headers).json()
        video_games = response['results']
        for i in video_games:
            collection.insert_one(i)
            print("Data Inserted")

# %%
get_games(games_base, pages_list, review_fields, reviews)

print(get_games)
# Out:
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# Data Inserted
# <function get_games at 0x0000028814612948>

# %%
scores = []
from pprint import pprint

for score in list(reviews.find({}, {"_id":0, "score": 10})):
    scores.append(score)

pprint(scores[:5])
# Out:
# [{'score': '10.0'},
#  {'score': '10.0'},
#  {'score': '10.0'},
#  {'score': '10.0'},
#  {'score': '10.0'}]

# %% [markdown]
# **2- Nobel Prize Data: https://nobelprize.readme.io/docs**

# %%
import requests
from pymongo import MongoClient
import requests
import pandas as pd

# %%
client = MongoClient()
client = MongoClient('127.0.0.1', 27017)

# connect to the database
db = client['nobel']

# %%
for collection_name in ["laureates"]:
    response = requests.get("http://api.nobelprize.org/v1/{}.json".\
                           format(collection_name[:-1]))

# %%
documents = response.json()[collection_name]

# %%
db[collection_name].insert_many(documents)

# %%
#No parameters in the find() method gives you the same result as SELECT * in MySQL.
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["nobel"]
nobel_data = mydb["laureates"]

# %%
#Return only the names and addresses, not the _ids:
for x in nobel_data.find({},{ "_id": 0, "firstname": 1, "born": 1 }):
  print(x)
# Out:
# {'firstname': 'Wilhelm Conrad', 'born': '1845-03-27'}
# {'firstname': 'Hendrik A.', 'born': '1853-07-18'}
# {'firstname': 'Pieter', 'born': '1865-05-25'}
# {'firstname': 'Henri', 'born': '1852-12-15'}
# {'firstname': 'Pierre', 'born': '1859-05-15'}
# {'firstname': 'Marie', 'born': '1867-11-07'}
# {'firstname': 'Lord', 'born': '1842-11-12'}
# {'firstname': 'Philipp', 'born': '1862-06-07'}
# {'firstname': 'J.J.', 'born': '1856-12-18'}
# {'firstname': 'Albert A.', 'born': '1852-12-19'}
# {'firstname': 'Gabriel', 'born': '1845-08-16'}
# {'firstname': 'Guglielmo', 'born': '1874-04-25'}
# {'firstname': 'Ferdinand', 'born': '1850-06-06'}
# {'firstname': 'Johannes Diderik', 'born': '1837-11-23'}
# {'firstname': 'Wilhelm', 'born': '1864-01-13'}
# {'firstname': 'Gustaf', 'born': '1869-11-30'}
# {'firstname': 'Heike', 'born': '1853-09-21'}
# {'firstname': 'Max', 'born': '1879-10-09'}
# {'firstname': 'William', 'born': '1862-07-02'}
# {'firstname': 'Lawrence', 'born': '1890-03-31'}
# {'firstname': 'Charles Glover', 'born': '1877-06-07'}
# {'firstname': 'Max', 'born': '1858-04-23'}
# {'firstname': 'Johannes', 'born': '1874-04-15'}
# {'firstname': 'Charles Edouard', 'born': '1861-02-15'}
# {'firstname': 'Albert', 'born': '1879-03-14'}
# {'firstname': 'Niels', 'born': '1885-10-07'}
# {'firstname': 'Robert A.', 'born': '1868-03-22'}
# {'firstname': 'Manne', 'born': '1886-12-03'}
# {'firstname': 'James', 'born': '1882-08-26'}
# {'firstname': 'Gustav', 'born': '1887-07-22'}
# {'firstname': 'Jean Baptiste', 'born': '1870-09-30'}
# {'firstname': 'Arthur H.', 'born': '1892-09-10'}
# {'firstname': 'C.T.R.', 'born': '1869-02-14'}
# {'firstname': 'Owen Willans', 'born': '1879-04-26'}
# {'firstname': 'Louis', 'born': '1892-08-15'}
# {'firstname': 'Sir Chandrasekhara Venkata', 'born': '1888-11-07'}
# {'firstname': 'Werner', 'born': '1901-12-05'}
# {'firstname': 'Erwin', 'born': '1887-08-12'}
# {'firstname': 'Paul A.M.', 'born': '1902-08-08'}
# {'firstname': 'James', 'born': '1891-10-20'}
# {'firstname': 'Victor F.', 'born': '1883-06-24'}
# {'firstname': 'Carl D.', 'born': '1905-09-03'}
# {'firstname': 'Clinton', 'born': '1881-10-22'}
# {'firstname': 'George Paget', 'born': '1892-05-03'}
# {'firstname': 'Enrico', 'born': '1901-09-29'}
# {'firstname': 'Ernest', 'born': '1901-08-08'}
# {'firstname': 'Otto', 'born': '1888-02-17'}
# {'firstname': 'Isidor Isaac', 'born': '1898-07-29'}
# {'firstname': 'Wolfgang', 'born': '1900-04-25'}
# {'firstname': 'Percy W.', 'born': '1882-04-21'}
# {'firstname': 'Edward V.', 'born': '1892-09-06'}
# {'firstname': 'Patrick M.S.', 'born': '1897-11-18'}
# {'firstname': 'Hideki', 'born': '1907-01-23'}
# {'firstname': 'Cecil', 'born': '1903-12-05'}
# {'firstname': 'John', 'born': '1897-05-27'}
# {'firstname': 'Ernest T.S.', 'born': '1903-10-06'}
# {'firstname': 'Felix', 'born': '1905-10-23'}
# {'firstname': 'E. M.', 'born': '1912-08-30'}
# {'firstname': 'Frits', 'born': '1888-07-16'}
# {'firstname': 'Max', 'born': '1882-12-11'}
# {'firstname': 'Walther', 'born': '1891-01-08'}
# {'firstname': 'Willis E.', 'born': '1913-07-12'}
# {'firstname': 'Polykarp', 'born': '1911-01-26'}
# {'firstname': 'William B.', 'born': '1910-02-13'}
# {'firstname': 'John', 'born': '1908-05-23'}
# {'firstname': 'Walter H.', 'born': '1902-02-10'}
# {'firstname': 'Chen Ning', 'born': '1922-09-22'}
# {'firstname': 'Tsung-Dao', 'born': '1926-11-24'}
# {'firstname': 'Pavel A.', 'born': '1904-07-28'}
# {'firstname': 'Igor Y.', 'born': '1895-07-08'}
# {'firstname': 'Emilio', 'born': '1905-02-01'}
# {'firstname': 'Owen', 'born': '1920-07-10'}
# {'firstname': 'Donald A.', 'born': '1926-09-21'}
# {'firstname': 'Robert', 'born': '1915-02-05'}
# {'firstname': 'Rudolf', 'born': '1929-01-31'}
# {'firstname': 'Lev', 'born': '1908-01-22'}
# {'firstname': 'Eugene', 'born': '1902-11-17'}
# {'firstname': 'Maria', 'born': '1906-06-28'}
# {'firstname': 'J. Hans D.', 'born': '1907-06-25'}
# {'firstname': 'Charles H.', 'born': '1915-07-28'}
# {'firstname': 'Nicolay G.', 'born': '1922-12-14'}
# {'firstname': 'Aleksandr M.', 'born': '1916-07-11'}
# {'firstname': 'Sin-Itiro', 'born': '1906-03-31'}
# {'firstname': 'Julian', 'born': '1918-02-12'}
# {'firstname': 'Richard P.', 'born': '1918-05-11'}
# {'firstname': 'Alfred', 'born': '1902-05-03'}
# {'firstname': 'Hans', 'born': '1906-07-02'}
# {'firstname': 'Luis', 'born': '1911-06-13'}
# {'firstname': 'Murray', 'born': '1929-09-15'}
# {'firstname': 'Hannes', 'born': '1908-05-30'}
# {'firstname': 'Louis', 'born': '1904-11-22'}
# {'firstname': 'Dennis', 'born': '1900-06-05'}
# {'firstname': 'Leon N.', 'born': '1930-02-28'}
# {'firstname': 'Robert', 'born': '1931-05-31'}
# {'firstname': 'Leo', 'born': '1925-03-12'}
# {'firstname': 'Ivar', 'born': '1929-04-05'}
# {'firstname': 'Brian D.', 'born': '1940-01-04'}
# {'firstname': 'Martin', 'born': '1918-09-27'}
# {'firstname': 'Antony', 'born': '1924-05-11'}
# {'firstname': 'Aage N.', 'born': '1922-06-19'}
# {'firstname': 'Ben R.', 'born': '1926-07-09'}
# {'firstname': 'James', 'born': '1917-12-09'}
# {'firstname': 'Burton', 'born': '1931-03-22'}
# {'firstname': 'Samuel C.C.', 'born': '1936-01-27'}
# {'firstname': 'Philip W.', 'born': '1923-12-13'}
# {'firstname': 'Sir Nevill F.', 'born': '1905-09-30'}
# {'firstname': 'John H.', 'born': '1899-03-13'}
# {'firstname': 'Pyotr', 'born': '1894-07-09'}
# {'firstname': 'Arno', 'born': '1933-04-26'}
# {'firstname': 'Robert Woodrow', 'born': '1936-01-10'}
# {'firstname': 'Sheldon', 'born': '1932-12-05'}
# {'firstname': 'Abdus', 'born': '1926-01-29'}
# {'firstname': 'Steven', 'born': '1933-05-03'}
# {'firstname': 'James', 'born': '1931-09-29'}
# {'firstname': 'Val', 'born': '1923-03-10'}
# {'firstname': 'Nicolaas', 'born': '1920-03-11'}
# {'firstname': 'Arthur L.', 'born': '1921-05-05'}
# {'firstname': 'Kai M.', 'born': '1918-04-20'}
# {'firstname': 'Kenneth G.', 'born': '1936-06-08'}
# {'firstname': 'Subramanyan', 'born': '1910-10-19'}
# {'firstname': 'William A.', 'born': '1911-08-09'}
# {'firstname': 'Carlo', 'born': '1934-03-31'}
# {'firstname': 'Simon', 'born': '1925-11-24'}
# {'firstname': 'Klaus', 'born': '1943-06-28'}
# {'firstname': 'Ernst', 'born': '1906-12-25'}
# {'firstname': 'Gerd', 'born': '1947-07-20'}
# {'firstname': 'Heinrich', 'born': '1933-06-06'}
# {'firstname': 'J. Georg', 'born': '1950-05-16'}
# {'firstname': 'K. Alex', 'born': '1927-04-20'}
# {'firstname': 'Leon M.', 'born': '1922-07-15'}
# {'firstname': 'Melvin', 'born': '1932-11-02'}
# {'firstname': 'Jack', 'born': '1921-05-25'}
# {'firstname': 'Norman F.', 'born': '1915-08-27'}
# {'firstname': 'Hans G.', 'born': '1922-09-09'}
# {'firstname': 'Wolfgang', 'born': '1913-08-10'}
# {'firstname': 'Jerome I.', 'born': '1930-03-28'}
# {'firstname': 'Henry W.', 'born': '1926-12-09'}
# {'firstname': 'Richard E.', 'born': '1929-11-02'}
# {'firstname': 'Pierre-Gilles', 'born': '1932-10-24'}
# {'firstname': 'Georges', 'born': '1924-08-01'}
# {'firstname': 'Russell A.', 'born': '1950-11-28'}
# {'firstname': 'Joseph H.', 'born': '1941-03-29'}
# {'firstname': 'Bertram N.', 'born': '1918-07-15'}
# {'firstname': 'Clifford G.', 'born': '1915-09-23'}
# {'firstname': 'Martin L.', 'born': '1927-06-24'}
# {'firstname': 'Frederick', 'born': '1918-03-16'}
# {'firstname': 'David M.', 'born': '1931-01-20'}
# {'firstname': 'Douglas D.', 'born': '1945-08-01'}
# {'firstname': 'Robert C.', 'born': '1937-06-26'}
# {'firstname': 'Steven', 'born': '1948-02-28'}
# {'firstname': 'Claude', 'born': '1933-04-01'}
# {'firstname': 'William D.', 'born': '1948-11-05'}
# {'firstname': 'Robert B.', 'born': '1950-11-01'}
# {'firstname': 'Horst L.', 'born': '1949-04-06'}
# {'firstname': 'Daniel C.', 'born': '1939-02-28'}
# {'firstname': 'Gerardus', 'born': '1946-07-05'}
# {'firstname': 'Martinus J.G.', 'born': '1931-06-27'}
# {'firstname': 'Jacobus H.', 'born': '1852-08-30'}
# {'firstname': 'Emil', 'born': '1852-10-09'}
# {'firstname': 'Svante', 'born': '1859-02-19'}
# {'firstname': 'Sir William', 'born': '1852-10-02'}
# {'firstname': 'Adolf', 'born': '1835-10-31'}
# {'firstname': 'Henri', 'born': '1852-09-28'}
# {'firstname': 'Eduard', 'born': '1860-05-20'}
# {'firstname': 'Ernest', 'born': '1871-08-30'}
# {'firstname': 'Wilhelm', 'born': '1853-09-02'}
# {'firstname': 'Otto', 'born': '1847-03-27'}
# {'firstname': 'Victor', 'born': '1871-05-06'}
# {'firstname': 'Paul', 'born': '1854-11-05'}
# {'firstname': 'Alfred', 'born': '1866-12-12'}
# {'firstname': 'Theodore W.', 'born': '1868-01-31'}
# {'firstname': 'Richard', 'born': '1872-08-13'}
# {'firstname': 'Fritz', 'born': '1868-12-09'}
# {'firstname': 'Walther', 'born': '1864-06-25'}
# {'firstname': 'Frederick', 'born': '1877-09-02'}
# {'firstname': 'Francis W.', 'born': '1877-09-01'}
# {'firstname': 'Fritz', 'born': '1869-09-03'}
# {'firstname': 'Richard', 'born': '1865-04-01'}
# {'firstname': 'The', 'born': '1884-08-30'}
# {'firstname': 'Heinrich', 'born': '1877-06-04'}
# {'firstname': 'Adolf', 'born': '1876-12-25'}
# {'firstname': 'Arthur', 'born': '1865-10-12'}
# {'firstname': 'Hans', 'born': '1873-02-15'}
# {'firstname': 'Hans', 'born': '1881-07-27'}
# {'firstname': 'Carl', 'born': '1874-08-27'}
# {'firstname': 'Friedrich', 'born': '1884-10-11'}
# {'firstname': 'Irving', 'born': '1881-01-31'}
# {'firstname': 'Harold C.', 'born': '1893-04-29'}
# {'firstname': 'Frédéric', 'born': '1900-03-19'}
# {'firstname': 'Irène', 'born': '1897-09-12'}
# {'firstname': 'Peter', 'born': '1884-03-24'}
# {'firstname': 'Norman', 'born': '1883-03-19'}
# {'firstname': 'Paul', 'born': '1889-04-21'}
# {'firstname': 'Richard', 'born': '1900-12-03'}
# {'firstname': 'Adolf', 'born': '1903-03-24'}
# {'firstname': 'Leopold', 'born': '1887-09-13'}
# {'firstname': 'George', 'born': '1885-08-01'}
# {'firstname': 'Otto', 'born': '1879-03-08'}
# {'firstname': 'Artturi', 'born': '1895-01-15'}
# {'firstname': 'James B.', 'born': '1887-11-19'}
# {'firstname': 'John H.', 'born': '1891-07-05'}
# {'firstname': 'Wendell M.', 'born': '1904-08-16'}
# {'firstname': 'Sir Robert', 'born': '1886-09-13'}
# {'firstname': 'Arne', 'born': '1902-08-10'}
# {'firstname': 'William F.', 'born': '1895-05-12'}
# {'firstname': 'Otto', 'born': '1876-01-23'}
# {'firstname': 'Kurt', 'born': '1902-07-10'}
# {'firstname': 'Edwin M.', 'born': '1907-09-18'}
# {'firstname': 'Glenn T.', 'born': '1912-04-19'}
# {'firstname': 'Archer J.P.', 'born': '1910-03-01'}
# {'firstname': 'Richard L.M.', 'born': '1914-10-28'}
# {'firstname': 'Hermann', 'born': '1881-03-23'}
# {'firstname': 'Linus', 'born': '1901-02-28'}
# {'firstname': 'Vincent', 'born': '1901-05-18'}
# {'firstname': 'Sir Cyril', 'born': '1897-05-19'}
# {'firstname': 'Nikolay', 'born': '1896-04-03'}
# {'firstname': 'Lord', 'born': '1907-10-02'}
# {'firstname': 'Frederick', 'born': '1918-08-13'}
# {'firstname': 'Jaroslav', 'born': '1890-12-20'}
# {'firstname': 'Willard F.', 'born': '1908-12-17'}
# {'firstname': 'Melvin', 'born': '1911-04-08'}
# {'firstname': 'Max F.', 'born': '1914-05-19'}
# {'firstname': 'John C.', 'born': '1917-03-24'}
# {'firstname': 'Karl', 'born': '1898-11-26'}
# {'firstname': 'Giulio', 'born': '1903-02-26'}
# {'firstname': 'Dorothy Crowfoot', 'born': '1910-05-12'}
# {'firstname': 'Robert B.', 'born': '1917-04-10'}
# {'firstname': 'Robert S.', 'born': '1896-06-07'}
# {'firstname': 'Manfred', 'born': '1927-05-09'}
# {'firstname': 'Ronald G.W.', 'born': '1897-11-09'}
# {'firstname': 'George', 'born': '1920-12-06'}
# {'firstname': 'Lars', 'born': '1903-11-27'}
# {'firstname': 'Derek', 'born': '1918-09-08'}
# {'firstname': 'Odd', 'born': '1897-05-17'}
# {'firstname': 'Luis', 'born': '1906-09-06'}
# {'firstname': 'Gerhard', 'born': '1904-12-25'}
# {'firstname': 'Christian', 'born': '1916-03-26'}
# {'firstname': 'Stanford', 'born': '1913-09-04'}
# {'firstname': 'William H.', 'born': '1911-06-25'}
# {'firstname': 'Ernst Otto', 'born': '1918-11-10'}
# {'firstname': 'Geoffrey', 'born': '1921-07-14'}
# {'firstname': 'Paul J.', 'born': '1910-06-19'}
# {'firstname': 'John', 'born': '1917-09-07'}
# {'firstname': 'Vladimir', 'born': '1906-07-23'}
# {'firstname': 'William', 'born': '1919-12-09'}
# {'firstname': 'Ilya', 'born': '1917-01-25'}
# {'firstname': 'Peter', 'born': '1920-09-29'}
# {'firstname': 'Herbert C.', 'born': '1912-05-22'}
# {'firstname': 'Georg', 'born': '1897-06-16'}
# {'firstname': 'Paul', 'born': '1926-06-30'}
# {'firstname': 'Walter', 'born': '1932-03-21'}
# {'firstname': 'Kenichi', 'born': '1918-10-04'}
# {'firstname': 'Roald', 'born': '1937-07-18'}
# {'firstname': 'Aaron', 'born': '1926-08-11'}
# {'firstname': 'Henry', 'born': '1915-11-30'}
# {'firstname': 'Bruce', 'born': '1921-07-15'}
# {'firstname': 'Herbert A.', 'born': '1917-02-14'}
# {'firstname': 'Jerome', 'born': '1918-06-18'}
# {'firstname': 'Dudley R.', 'born': '1932-06-18'}
# {'firstname': 'Yuan T.', 'born': '1936-11-19'}
# {'firstname': 'John C.', 'born': '1929-01-23'}
# {'firstname': 'Donald J.', 'born': '1919-04-22'}
# {'firstname': 'Jean-Marie', 'born': '1939-09-30'}
# {'firstname': 'Charles J.', 'born': '1904-10-03'}
# {'firstname': 'Johann', 'born': '1943-09-30'}
# {'firstname': 'Robert', 'born': '1937-02-20'}
# {'firstname': 'Hartmut', 'born': '1948-07-18'}
# {'firstname': 'Sidney', 'born': '1939-05-07'}
# {'firstname': 'Thomas R.', 'born': '1947-12-08'}
# {'firstname': 'Elias James', 'born': '1928-07-12'}
# {'firstname': 'Richard R.', 'born': '1933-08-14'}
# {'firstname': 'Rudolph A.', 'born': '1923-07-21'}
# {'firstname': 'Kary B.', 'born': '1944-12-28'}
# {'firstname': 'Michael', 'born': '1932-04-26'}
# {'firstname': 'George A.', 'born': '1927-05-22'}
# {'firstname': 'Paul J.', 'born': '1933-12-03'}
# {'firstname': 'Mario J.', 'born': '1943-03-19'}
# {'firstname': 'F. Sherwood', 'born': '1927-06-28'}
# {'firstname': 'Robert F.', 'born': '1933-08-23'}
# {'firstname': 'Sir Harold', 'born': '1939-10-07'}
# {'firstname': 'Richard E.', 'born': '1943-06-06'}
# {'firstname': 'Paul D.', 'born': '1918-07-31'}
# {'firstname': 'John E.', 'born': '1941-01-07'}
# {'firstname': 'Jens C.', 'born': '1918-10-08'}
# {'firstname': 'Walter', 'born': '1923-03-09'}
# {'firstname': 'John', 'born': '1925-10-31'}
# {'firstname': 'Ahmed', 'born': '1946-02-26'}
# {'firstname': 'Emil', 'born': '1854-03-15'}
# {'firstname': 'Ronald', 'born': '1857-05-13'}
# {'firstname': 'Niels Ryberg', 'born': '1860-12-15'}
# {'firstname': 'Ivan', 'born': '1849-09-14'}
# {'firstname': 'Robert', 'born': '1843-12-11'}
# {'firstname': 'Camillo', 'born': '1843-07-07'}
# {'firstname': 'Santiago', 'born': '1852-05-01'}
# {'firstname': 'Alphonse', 'born': '1845-06-18'}
# {'firstname': 'Ilya', 'born': '1845-05-15'}
# {'firstname': 'Paul', 'born': '1854-03-14'}
# {'firstname': 'Theodor', 'born': '1841-08-25'}
# {'firstname': 'Albrecht', 'born': '1853-09-16'}
# {'firstname': 'Allvar', 'born': '1862-06-05'}
# {'firstname': 'Alexis', 'born': '1873-06-28'}
# {'firstname': 'Charles', 'born': '1850-08-26'}
# {'firstname': 'Robert', 'born': '1876-04-22'}
# {'firstname': 'Jules', 'born': '1870-06-13'}
# {'firstname': 'August', 'born': '1874-11-15'}
# {'firstname': 'Archibald V.', 'born': '1886-09-26'}
# {'firstname': 'Otto', 'born': '1884-04-12'}
# {'firstname': 'Frederick G.', 'born': '1891-11-14'}
# {'firstname': 'John', 'born': '1876-09-06'}
# {'firstname': 'Willem', 'born': '1860-05-21'}
# {'firstname': 'Johannes', 'born': '1867-04-23'}
# {'firstname': 'Julius', 'born': '1857-03-07'}
# {'firstname': 'Charles', 'born': '1866-09-21'}
# {'firstname': 'Christiaan', 'born': '1858-08-11'}
# {'firstname': 'Sir Frederick', 'born': '1861-06-20'}
# {'firstname': 'Karl', 'born': '1868-06-14'}
# {'firstname': 'Otto', 'born': '1883-10-08'}
# {'firstname': 'Sir Charles', 'born': '1857-11-27'}
# {'firstname': 'Edgar', 'born': '1889-11-30'}
# {'firstname': 'Thomas H.', 'born': '1866-09-25'}
# {'firstname': 'George H.', 'born': '1878-08-28'}
# {'firstname': 'George R.', 'born': '1885-12-02'}
# {'firstname': 'William P.', 'born': '1892-02-06'}
# {'firstname': 'Hans', 'born': '1869-06-27'}
# {'firstname': 'Sir Henry', 'born': '1875-06-09'}
# {'firstname': 'Otto', 'born': '1873-06-03'}
# {'firstname': 'Albert', 'born': '1893-09-16'}
# {'firstname': 'Corneille', 'born': '1892-03-28'}
# {'firstname': 'Gerhard', 'born': '1895-10-30'}
# {'firstname': 'Henrik', 'born': '1895-02-21'}
# {'firstname': 'Edward A.', 'born': '1893-11-13'}
# {'firstname': 'Joseph', 'born': '1874-01-05'}
# {'firstname': 'Herbert S.', 'born': '1888-07-05'}
# {'firstname': 'Sir Alexander', 'born': '1881-08-06'}
# {'firstname': 'Ernst B.', 'born': '1906-06-19'}
# {'firstname': 'Sir Howard', 'born': '1898-09-24'}
# {'firstname': 'Hermann J.', 'born': '1890-12-21'}
# {'firstname': 'Carl', 'born': '1896-12-05'}
# {'firstname': 'Gerty', 'born': '1896-08-15'}
# {'firstname': 'Bernardo', 'born': '1887-04-10'}
# {'firstname': 'Paul', 'born': '1899-01-12'}
# {'firstname': 'Walter', 'born': '1881-03-17'}
# {'firstname': 'Egas', 'born': '1874-11-29'}
# {'firstname': 'Edward C.', 'born': '1886-03-08'}
# {'firstname': 'Tadeus', 'born': '1897-07-20'}
# {'firstname': 'Philip S.', 'born': '1896-02-28'}
# {'firstname': 'Max', 'born': '1899-01-30'}
# {'firstname': 'Selman A.', 'born': '1888-07-22'}
# {'firstname': 'Hans', 'born': '1900-08-25'}
# {'firstname': 'Fritz', 'born': '1899-06-12'}
# {'firstname': 'John F.', 'born': '1897-02-10'}
# {'firstname': 'Thomas H.', 'born': '1915-06-15'}
# {'firstname': 'Frederick C.', 'born': '1916-08-25'}
# {'firstname': 'Hugo', 'born': '1903-07-06'}
# {'firstname': 'André F.', 'born': '1895-09-24'}
# {'firstname': 'Werner', 'born': '1904-08-29'}
# {'firstname': 'Dickinson W.', 'born': '1895-10-30'}
# {'firstname': 'Daniel', 'born': '1907-03-23'}
# {'firstname': 'George', 'born': '1903-10-22'}
# {'firstname': 'Edward', 'born': '1909-12-14'}
# {'firstname': 'Joshua', 'born': '1925-05-23'}
# {'firstname': 'Severo', 'born': '1905-09-24'}
# {'firstname': 'Arthur', 'born': '1918-03-03'}
# {'firstname': 'Sir Frank Macfarlane', 'born': '1899-09-03'}
# {'firstname': 'Peter', 'born': '1915-02-28'}
# {'firstname': 'Georg', 'born': '1899-06-03'}
# {'firstname': 'Francis', 'born': '1916-06-08'}
# {'firstname': 'James', 'born': '1928-04-06'}
# {'firstname': 'Maurice', 'born': '1916-12-15'}
# {'firstname': 'Sir John', 'born': '1903-01-27'}
# {'firstname': 'Alan', 'born': '1914-02-05'}
# {'firstname': 'Andrew', 'born': '1917-11-22'}
# {'firstname': 'Konrad', 'born': '1912-01-21'}
# {'firstname': 'Feodor', 'born': '1911-04-06'}
# {'firstname': 'François', 'born': '1920-06-17'}
# {'firstname': 'André', 'born': '1902-05-08'}
# {'firstname': 'Jacques', 'born': '1910-02-09'}
# {'firstname': 'Peyton', 'born': '1879-10-05'}
# {'firstname': 'Charles B.', 'born': '1901-09-22'}
# {'firstname': 'Ragnar', 'born': '1900-10-30'}
# {'firstname': 'Keffer', 'born': '1903-12-22'}
# {'firstname': 'George', 'born': '1906-11-18'}
# {'firstname': 'Robert W.', 'born': '1922-01-28'}
# {'firstname': 'H. Gobind', 'born': '1922-01-09'}
# {'firstname': 'Marshall W.', 'born': '1927-04-10'}
# {'firstname': 'Max', 'born': '1906-09-04'}
# {'firstname': 'Alfred D.', 'born': '1908-12-04'}
# {'firstname': 'Salvador E.', 'born': '1912-08-13'}
# {'firstname': 'Sir Bernard', 'born': '1911-03-26'}
# {'firstname': 'Ulf', 'born': '1905-02-07'}
# {'firstname': 'Julius', 'born': '1912-05-30'}
# {'firstname': 'Earl W.', 'born': '1915-11-19'}
# {'firstname': 'Gerald M.', 'born': '1929-07-01'}
# {'firstname': 'Rodney R.', 'born': '1917-10-08'}
# {'firstname': 'Karl', 'born': '1886-11-20'}
# {'firstname': 'Konrad', 'born': '1903-11-07'}
# {'firstname': 'Nikolaas', 'born': '1907-04-15'}
# {'firstname': 'Albert', 'born': '1898-08-24'}
# {'firstname': 'Christian', 'born': '1917-10-02'}
# {'firstname': 'George E.', 'born': '1912-11-19'}
# {'firstname': 'David', 'born': '1938-03-07'}
# {'firstname': 'Renato', 'born': '1914-02-22'}
# {'firstname': 'Howard M.', 'born': '1934-12-10'}
# {'firstname': 'Baruch S.', 'born': '1925-07-28'}
# {'firstname': 'D. Carleton', 'born': '1923-09-09'}
# {'firstname': 'Roger', 'born': '1924-01-11'}
# {'firstname': 'Andrew V.', 'born': '1926-11-30'}
# {'firstname': 'Rosalyn', 'born': '1921-07-19'}
# {'firstname': 'Werner', 'born': '1929-06-03'}
# {'firstname': 'Daniel', 'born': '1928-10-30'}
# {'firstname': 'Hamilton O.', 'born': '1931-08-23'}
# {'firstname': 'Allan M.', 'born': '1924-02-23'}
# {'firstname': 'Godfrey N.', 'born': '1919-08-28'}
# {'firstname': 'Baruj', 'born': '1920-10-29'}
# {'firstname': 'Jean', 'born': '1916-10-19'}
# {'firstname': 'George D.', 'born': '1903-12-19'}
# {'firstname': 'Roger W.', 'born': '1913-08-20'}
# {'firstname': 'David H.', 'born': '1926-02-27'}
# {'firstname': 'Torsten N.', 'born': '1924-06-03'}
# {'firstname': 'Sune K.', 'born': '1916-01-10'}
# {'firstname': 'Bengt I.', 'born': '1934-05-21'}
# {'firstname': 'John R.', 'born': '1927-03-29'}
# {'firstname': 'Barbara', 'born': '1902-06-16'}
# {'firstname': 'Niels K.', 'born': '1911-12-23'}
# {'firstname': 'Georges J.F.', 'born': '1946-04-17'}
# {'firstname': 'César', 'born': '1927-10-08'}
# {'firstname': 'Michael S.', 'born': '1941-04-13'}
# {'firstname': 'Joseph L.', 'born': '1940-04-18'}
# {'firstname': 'Stanley', 'born': '1922-11-17'}
# {'firstname': 'Rita', 'born': '1909-04-22'}
# {'firstname': 'Susumu', 'born': '1939-09-05'}
# {'firstname': 'Sir James W.', 'born': '1924-06-14'}
# {'firstname': 'Gertrude B.', 'born': '1918-01-23'}
# {'firstname': 'George H.', 'born': '1905-04-18'}
# {'firstname': 'J. Michael', 'born': '1936-02-22'}
# {'firstname': 'Harold E.', 'born': '1939-12-18'}
# {'firstname': 'Joseph E.', 'born': '1919-04-01'}
# {'firstname': 'E. Donnall', 'born': '1920-03-15'}
# {'firstname': 'Erwin', 'born': '1944-03-20'}
# {'firstname': 'Bert', 'born': '1942-06-12'}
# {'firstname': 'Edmond H.', 'born': '1920-04-06'}
# {'firstname': 'Edwin G.', 'born': '1918-06-06'}
# {'firstname': 'Richard J.', 'born': '1943-09-06'}
# {'firstname': 'Phillip A.', 'born': '1944-06-06'}
# {'firstname': 'Alfred G.', 'born': '1941-07-01'}
# {'firstname': 'Martin', 'born': '1925-12-01'}
# {'firstname': 'Edward B.', 'born': '1918-05-20'}
# {'firstname': 'Christiane', 'born': '1942-10-20'}
# {'firstname': 'Eric F.', 'born': '1947-06-08'}
# {'firstname': 'Peter C.', 'born': '1940-10-15'}
# {'firstname': 'Rolf M.', 'born': '1944-01-06'}
# {'firstname': 'Stanley B.', 'born': '1942-05-28'}
# {'firstname': 'Robert F.', 'born': '1916-06-04'}
# {'firstname': 'Louis J.', 'born': '1941-05-31'}
# {'firstname': 'Ferid', 'born': '1936-09-14'}
# {'firstname': 'Günter', 'born': '1936-05-21'}
# {'firstname': 'Henry', 'born': '1828-05-08'}
# {'firstname': 'Frédéric', 'born': '1822-05-20'}
# {'firstname': 'Élie', 'born': '1833-02-19'}
# {'firstname': 'Albert', 'born': '1843-05-21'}
# {'firstname': 'Randal', 'born': '1828-03-18'}
# {'firstname': 'Institute of International Law', 'born': '1873-00-00'}
# {'firstname': 'Bertha', 'born': '1843-06-09'}
# {'firstname': 'Theodore', 'born': '1858-10-27'}
# {'firstname': 'Ernesto Teodoro', 'born': '1833-09-20'}
# {'firstname': 'Louis', 'born': '1843-05-21'}
# {'firstname': 'Klas Pontus', 'born': '1844-10-27'}
# {'firstname': 'Fredrik', 'born': '1837-04-21'}
# {'firstname': 'Auguste', 'born': '1829-07-26'}
# {'firstname': 'Paul Henri', 'born': '1852-11-22'}
# {'firstname': 'Permanent International Peace Bureau', 'born': '1891-00-00'}
# {'firstname': 'Tobias', 'born': '1838-04-28'}
# {'firstname': 'Alfred', 'born': '1864-11-11'}
# {'firstname': 'Elihu', 'born': '1845-02-15'}
# {'firstname': 'Henri', 'born': '1854-04-22'}
# {'firstname': 'International Committee of the Red Cross', 'born': '1863-00-00'}
# {'firstname': 'Woodrow', 'born': '1856-12-28'}
# {'firstname': 'Léon', 'born': '1851-05-21'}
# {'firstname': 'Hjalmar', 'born': '1860-11-23'}
# {'firstname': 'Christian', 'born': '1869-09-17'}
# {'firstname': 'Fridtjof', 'born': '1861-10-10'}
# {'firstname': 'Sir Austen', 'born': '1863-10-16'}
# {'firstname': 'Charles G.', 'born': '1865-08-27'}
# {'firstname': 'Aristide', 'born': '1862-03-28'}
# {'firstname': 'Gustav', 'born': '1878-05-10'}
# {'firstname': 'Ferdinand', 'born': '1841-12-20'}
# {'firstname': 'Ludwig', 'born': '1858-03-23'}
# {'firstname': 'Frank B.', 'born': '1856-12-22'}
# {'firstname': 'Nathan', 'born': '1866-01-15'}
# {'firstname': 'Jane', 'born': '1860-09-06'}
# {'firstname': 'Nicholas Murray', 'born': '1862-04-02'}
# {'firstname': 'Sir Norman', 'born': '1872-12-26'}
# {'firstname': 'Arthur', 'born': '1863-09-13'}
# {'firstname': 'Carl', 'born': '1889-10-03'}
# {'firstname': 'Carlos', 'born': '1878-11-01'}
# {'firstname': 'Robert', 'born': '1864-09-14'}
# {'firstname': 'Nansen International Office for Refugees', 'born': '1921-00-00'}
# {'firstname': 'Cordell', 'born': '1871-10-02'}
# {'firstname': 'Emily Greene', 'born': '1867-01-08'}
# {'firstname': 'John R.', 'born': '1865-05-25'}
# {'firstname': 'Friends Service Council', 'born': '1647-00-00'}
# {'firstname': 'American Friends Service Committee', 'born': '1917-00-00'}
# {'firstname': 'John', 'born': '1880-09-23'}
# {'firstname': 'Ralph', 'born': '1904-08-07'}
# {'firstname': 'Léon', 'born': '1879-07-01'}
# {'firstname': 'Albert', 'born': '1875-01-14'}
# {'firstname': 'George C.', 'born': '1880-12-31'}
# {'firstname': 'Office of the United Nations High Commissioner for Refugees', 'born': '1950-12-14'}
# {'firstname': 'Lester Bowles', 'born': '1897-04-23'}
# {'firstname': 'Georges', 'born': '1910-02-10'}
# {'firstname': 'Philip', 'born': '1889-11-01'}
# {'firstname': 'Albert', 'born': '1898-00-00'}
# {'firstname': 'Dag', 'born': '1905-07-29'}
# {'firstname': 'League of Red Cross Societies', 'born': '1919-00-00'}
# {'firstname': 'Martin Luther', 'born': '1929-01-15'}
# {'firstname': "United Nations Children's Fund", 'born': '1946-00-00'}
# {'firstname': 'René', 'born': '1887-10-05'}
# {'firstname': 'International Labour Organization', 'born': '1919-00-00'}
# {'firstname': 'Norman', 'born': '1914-03-25'}
# {'firstname': 'Willy', 'born': '1913-12-18'}
# {'firstname': 'Henry', 'born': '1923-05-27'}
# {'firstname': 'Le Duc Tho', 'born': '1911-10-14'}
# {'firstname': 'Seán', 'born': '1904-01-26'}
# {'firstname': 'Eisaku', 'born': '1901-03-27'}
# {'firstname': 'Andrei', 'born': '1921-05-21'}
# {'firstname': 'Betty', 'born': '1943-05-22'}
# {'firstname': 'Mairead', 'born': '1944-01-27'}
# {'firstname': 'Amnesty International', 'born': '1961-00-00'}
# {'firstname': 'Anwar', 'born': '1918-12-25'}
# {'firstname': 'Menachem', 'born': '1913-08-16'}
# {'firstname': 'Anjezë Gonxhe', 'born': '1910-08-26'}
# {'firstname': 'Adolfo', 'born': '1931-11-26'}
# {'firstname': 'Alva', 'born': '1902-01-31'}
# {'firstname': 'Alfonso', 'born': '1911-03-20'}
# {'firstname': 'Lech', 'born': '1943-09-29'}
# {'firstname': 'Desmond', 'born': '1931-10-07'}
# {'firstname': 'International Physicians for the Prevention of Nuclear War', 'born': '1980-00-00'}
# {'firstname': 'Elie', 'born': '1928-09-30'}
# {'firstname': 'Oscar', 'born': '1940-09-13'}
# {'firstname': 'United Nations Peacekeeping Forces', 'born': '1948-00-00'}
# {'firstname': 'Lhamo', 'born': '1935-07-06'}
# {'firstname': 'Mikhail', 'born': '1931-03-02'}
# {'firstname': 'Aung San Suu Kyi', 'born': '1945-06-19'}
# {'firstname': 'Rigoberta', 'born': '1959-01-09'}
# {'firstname': 'Nelson', 'born': '1918-07-18'}
# {'firstname': 'F.W.', 'born': '1936-03-18'}
# {'firstname': 'Yasser', 'born': '1929-08-24'}
# {'firstname': 'Shimon', 'born': '1923-08-16'}
# {'firstname': 'Yitzhak', 'born': '1922-03-01'}
# {'firstname': 'Joseph', 'born': '1908-11-04'}
# {'firstname': 'Pugwash Conferences on Science and World Affairs', 'born': '1957-00-00'}
# {'firstname': 'Carlos Filipe Ximenes', 'born': '1948-02-03'}
# {'firstname': 'José', 'born': '1949-12-26'}
# {'firstname': 'International Campaign to Ban Landmines', 'born': '1992-00-00'}
# {'firstname': 'Jody', 'born': '1950-10-09'}
# {'firstname': 'John', 'born': '1937-01-18'}
# {'firstname': 'David', 'born': '1944-10-15'}
# {'firstname': 'Médecins Sans Frontières', 'born': '1971-00-00'}
# {'firstname': 'Sully', 'born': '1839-03-16'}
# {'firstname': 'Theodor', 'born': '1817-11-30'}
# {'firstname': 'Bjørnstjerne', 'born': '1832-12-08'}
# {'firstname': 'Frédéric', 'born': '1830-09-08'}
# {'firstname': 'José', 'born': '1832-04-19'}
# {'firstname': 'Henryk', 'born': '1846-05-05'}
# {'firstname': 'Giosuè', 'born': '1835-07-27'}
# {'firstname': 'Rudyard', 'born': '1865-12-30'}
# {'firstname': 'Rudolf', 'born': '1846-01-05'}
# {'firstname': 'Selma', 'born': '1858-11-20'}
# {'firstname': 'Paul', 'born': '1830-03-15'}
# {'firstname': 'Maurice', 'born': '1862-08-29'}
# {'firstname': 'Gerhart', 'born': '1862-11-15'}
# {'firstname': 'Rabindranath', 'born': '1861-05-07'}
# {'firstname': 'Romain', 'born': '1866-01-29'}
# {'firstname': 'Verner', 'born': '1859-07-06'}
# {'firstname': 'Karl', 'born': '1857-06-02'}
# {'firstname': 'Henrik', 'born': '1857-07-24'}
# {'firstname': 'Carl', 'born': '1845-04-24'}
# {'firstname': 'Knut', 'born': '1859-08-04'}
# {'firstname': 'Anatole', 'born': '1844-04-16'}
# {'firstname': 'Jacinto', 'born': '1866-08-12'}
# {'firstname': 'William Butler', 'born': '1865-06-13'}
# {'firstname': 'Wladyslaw', 'born': '1867-05-07'}
# {'firstname': 'George Bernard', 'born': '1856-07-26'}
# {'firstname': 'Grazia', 'born': '1871-09-27'}
# {'firstname': 'Henri', 'born': '1859-10-18'}
# {'firstname': 'Sigrid', 'born': '1882-05-20'}
# {'firstname': 'Thomas', 'born': '1875-06-06'}
# {'firstname': 'Sinclair', 'born': '1885-02-07'}
# {'firstname': 'Erik Axel', 'born': '1864-07-20'}
# {'firstname': 'John', 'born': '1867-08-14'}
# {'firstname': 'Ivan', 'born': '1870-10-22'}
# {'firstname': 'Luigi', 'born': '1867-06-28'}
# {'firstname': 'Eugene', 'born': '1888-10-16'}
# {'firstname': 'Roger', 'born': '1881-03-23'}
# {'firstname': 'Pearl', 'born': '1892-06-26'}
# {'firstname': 'Frans Eemil', 'born': '1888-09-16'}
# {'firstname': 'Johannes V.', 'born': '1873-01-20'}
# {'firstname': 'Gabriela', 'born': '1889-04-07'}
# {'firstname': 'Hermann', 'born': '1877-07-02'}
# {'firstname': 'André', 'born': '1869-11-22'}
# {'firstname': 'T.S.', 'born': '1888-09-26'}
# {'firstname': 'William', 'born': '1897-09-25'}
# {'firstname': 'Bertrand', 'born': '1872-05-18'}
# {'firstname': 'Pär', 'born': '1891-05-23'}
# {'firstname': 'François', 'born': '1885-10-11'}
# {'firstname': 'Winston', 'born': '1874-11-30'}
# {'firstname': 'Ernest', 'born': '1899-07-21'}
# {'firstname': 'Halldór', 'born': '1902-04-23'}
# {'firstname': 'Juan Ramón', 'born': '1881-12-24'}
# {'firstname': 'Albert', 'born': '1913-11-07'}
# {'firstname': 'Boris', 'born': '1890-02-10'}
# {'firstname': 'Salvatore', 'born': '1901-08-20'}
# {'firstname': 'Saint-John', 'born': '1887-05-31'}
# {'firstname': 'Ivo', 'born': '1892-10-10'}
# {'firstname': 'John', 'born': '1902-02-27'}
# {'firstname': 'Giorgos', 'born': '1900-03-13'}
# {'firstname': 'Jean-Paul', 'born': '1905-06-21'}
# {'firstname': 'Mikhail', 'born': '1905-05-24'}
# {'firstname': 'Shmuel', 'born': '1888-07-17'}
# {'firstname': 'Nelly', 'born': '1891-12-10'}
# {'firstname': 'Miguel Angel', 'born': '1899-10-19'}
# {'firstname': 'Yasunari', 'born': '1899-06-11'}
# {'firstname': 'Samuel', 'born': '1906-04-13'}
# {'firstname': 'Alexandr', 'born': '1918-12-11'}
# {'firstname': 'Pablo', 'born': '1904-07-12'}
# {'firstname': 'Heinrich', 'born': '1917-12-21'}
# {'firstname': 'Patrick', 'born': '1912-05-28'}
# {'firstname': 'Eyvind', 'born': '1900-07-29'}
# {'firstname': 'Harry', 'born': '1904-05-06'}
# {'firstname': 'Eugenio', 'born': '1896-10-12'}
# {'firstname': 'Saul', 'born': '1915-06-10'}
# {'firstname': 'Vicente', 'born': '1898-04-26'}
# {'firstname': 'Isaac Bashevis', 'born': '1904-07-14'}
# {'firstname': 'Odysseus', 'born': '1911-11-02'}
# {'firstname': 'Czeslaw', 'born': '1911-06-30'}
# {'firstname': 'Elias', 'born': '1905-07-25'}
# {'firstname': 'Gabriel', 'born': '1927-03-06'}
# {'firstname': 'William', 'born': '1911-09-19'}
# {'firstname': 'Jaroslav', 'born': '1901-09-23'}
# {'firstname': 'Claude', 'born': '1913-10-10'}
# {'firstname': 'Wole', 'born': '1934-07-13'}
# {'firstname': 'Joseph', 'born': '1940-05-24'}
# {'firstname': 'Naguib', 'born': '1911-12-11'}
# {'firstname': 'Camilo José', 'born': '1916-05-11'}
# {'firstname': 'Octavio', 'born': '1914-03-31'}
# {'firstname': 'Nadine', 'born': '1923-11-20'}
# {'firstname': 'Derek', 'born': '1930-01-23'}
# {'firstname': 'Toni', 'born': '1931-02-18'}
# {'firstname': 'Kenzaburo', 'born': '1935-01-31'}
# {'firstname': 'Seamus', 'born': '1939-04-13'}
# {'firstname': 'Wislawa', 'born': '1923-07-02'}
# {'firstname': 'Dario', 'born': '1926-03-24'}
# {'firstname': 'José', 'born': '1922-11-16'}
# {'firstname': 'Günter', 'born': '1927-10-16'}
# {'firstname': 'Ragnar', 'born': '1895-03-03'}
# {'firstname': 'Jan', 'born': '1903-04-12'}
# {'firstname': 'Paul A.', 'born': '1915-05-15'}
# {'firstname': 'Simon', 'born': '1901-04-30'}
# {'firstname': 'John R.', 'born': '1904-04-08'}
# {'firstname': 'Kenneth J.', 'born': '1921-08-23'}
# {'firstname': 'Wassily', 'born': '1906-08-05'}
# {'firstname': 'Gunnar', 'born': '1898-12-06'}
# {'firstname': 'Friedrich', 'born': '1899-05-08'}
# {'firstname': 'Leonid Vitaliyevich', 'born': '1912-01-19'}
# {'firstname': 'Tjalling C.', 'born': '1910-08-28'}
# {'firstname': 'Milton', 'born': '1912-07-31'}
# {'firstname': 'Bertil', 'born': '1899-04-23'}
# {'firstname': 'James E.', 'born': '1907-06-23'}
# {'firstname': 'Herbert', 'born': '1916-06-15'}
# {'firstname': 'Theodore W.', 'born': '1902-04-30'}
# {'firstname': 'Sir Arthur', 'born': '1915-01-23'}
# {'firstname': 'Lawrence R.', 'born': '1920-09-14'}
# {'firstname': 'James', 'born': '1918-03-05'}
# {'firstname': 'George J.', 'born': '1911-01-17'}
# {'firstname': 'Gerard', 'born': '1921-07-04'}
# {'firstname': 'Richard', 'born': '1913-08-30'}
# {'firstname': 'Franco', 'born': '1918-06-18'}
# {'firstname': 'James M.', 'born': '1919-10-03'}
# {'firstname': 'Robert M.', 'born': '1924-08-23'}
# {'firstname': 'Maurice', 'born': '1911-05-31'}
# {'firstname': 'Trygve', 'born': '1911-12-13'}
# {'firstname': 'Harry M.', 'born': '1927-08-24'}
# {'firstname': 'Merton H.', 'born': '1923-05-16'}
# {'firstname': 'William F.', 'born': '1934-06-16'}
# {'firstname': 'Ronald H.', 'born': '1910-12-29'}
# {'firstname': 'Gary', 'born': '1930-12-02'}
# {'firstname': 'Robert W.', 'born': '1927-07-01'}
# {'firstname': 'Douglass C.', 'born': '1920-11-05'}
# {'firstname': 'John C.', 'born': '1920-05-29'}
# {'firstname': 'John F.', 'born': '1928-06-13'}
# {'firstname': 'Reinhard', 'born': '1930-10-05'}
# {'firstname': 'Robert E.', 'born': '1937-09-15'}
# {'firstname': 'James A.', 'born': '1936-07-05'}
# {'firstname': 'William', 'born': '1914-06-21'}
# {'firstname': 'Robert C.', 'born': '1944-07-31'}
# {'firstname': 'Myron', 'born': '1941-07-01'}
# {'firstname': 'Amartya', 'born': '1933-11-03'}
# {'firstname': 'Robert', 'born': '1932-10-24'}
# {'firstname': 'Il´ja M.', 'born': '1908-10-23'}
# {'firstname': 'Arvid', 'born': '1923-01-25'}
# {'firstname': 'Paul', 'born': '1925-12-11'}
# {'firstname': 'Eric', 'born': '1929-11-07'}
# {'firstname': 'Kim', 'born': '1925-12-03'}
# {'firstname': 'Zhores', 'born': '1930-03-15'}
# {'firstname': 'Herbert', 'born': '1928-08-25'}
# {'firstname': 'Jack', 'born': '1923-11-08'}
# {'firstname': 'Alan', 'born': '1936-01-22'}
# {'firstname': 'Alan', 'born': '1927-04-14'}
# {'firstname': 'Hideki', 'born': '1936-08-20'}
# {'firstname': 'James J.', 'born': '1944-04-19'}
# {'firstname': 'Daniel L.', 'born': '1937-07-29'}
# {'firstname': 'Xingjian', 'born': '1940-01-04'}
# {'firstname': 'Leland', 'born': '1939-10-30'}
# {'firstname': 'Tim', 'born': '1943-02-19'}
# {'firstname': 'Sir Paul', 'born': '1949-01-25'}
# {'firstname': 'Eric', 'born': '1961-12-19'}
# {'firstname': 'Wolfgang', 'born': '1957-10-21'}
# {'firstname': 'Carl', 'born': '1951-03-26'}
# {'firstname': 'William', 'born': '1917-06-01'}
# {'firstname': 'Ryoji', 'born': '1938-09-03'}
# {'firstname': 'Barry', 'born': '1941-04-28'}
# {'firstname': 'George A.', 'born': '1940-06-17'}
# {'firstname': 'A. Michael', 'born': '1943-00-00'}
# {'firstname': 'Joseph E.', 'born': '1943-02-09'}
# {'firstname': 'V. S.', 'born': '1932-08-17'}
# {'firstname': 'United Nations', 'born': '1945-00-00'}
# {'firstname': 'Kofi', 'born': '1938-04-08'}
# {'firstname': 'Sydney', 'born': '1927-01-13'}
# {'firstname': 'H. Robert', 'born': '1947-05-08'}
# {'firstname': 'John E.', 'born': '1942-03-27'}
# {'firstname': 'Raymond', 'born': '1914-10-14'}
# {'firstname': 'Masatoshi', 'born': '1926-09-19'}
# {'firstname': 'Riccardo', 'born': '1931-10-06'}
# {'firstname': 'John B.', 'born': '1917-06-15'}
# {'firstname': 'Koichi', 'born': '1959-08-03'}
# {'firstname': 'Kurt', 'born': '1938-10-04'}
# {'firstname': 'Daniel', 'born': '1934-03-05'}
# {'firstname': 'Vernon L.', 'born': '1927-01-01'}
# {'firstname': 'Imre', 'born': '1929-11-09'}
# {'firstname': 'Jimmy', 'born': '1924-10-01'}
# {'firstname': 'J. M.', 'born': '1940-02-09'}
# {'firstname': 'Paul C.', 'born': '1929-05-06'}
# {'firstname': 'Sir Peter', 'born': '1933-10-09'}
# {'firstname': 'Alexei', 'born': '1928-06-25'}
# {'firstname': 'Vitaly L.', 'born': '1916-10-04'}
# {'firstname': 'Anthony J.', 'born': '1938-03-26'}
# {'firstname': 'Peter', 'born': '1949-01-30'}
# {'firstname': 'Roderick', 'born': '1956-02-19'}
# {'firstname': 'Robert F.', 'born': '1942-11-10'}
# {'firstname': 'Clive W.J.', 'born': '1934-09-04'}
# {'firstname': 'Shirin', 'born': '1947-06-21'}
# {'firstname': 'Richard', 'born': '1946-07-02'}
# {'firstname': 'Linda B.', 'born': '1947-01-29'}
# {'firstname': 'David J.', 'born': '1941-02-19'}
# {'firstname': 'H. David', 'born': '1949-08-31'}
# {'firstname': 'Frank', 'born': '1951-05-15'}
# {'firstname': 'Aaron', 'born': '1947-10-01'}
# {'firstname': 'Avram', 'born': '1937-12-31'}
# {'firstname': 'Irwin', 'born': '1926-07-16'}
# {'firstname': 'Elfriede', 'born': '1946-10-20'}
# {'firstname': 'Wangari', 'born': '1940-04-01'}
# {'firstname': 'Finn E.', 'born': '1943-12-01'}
# {'firstname': 'Edward C.', 'born': '1940-12-26'}
# {'firstname': 'Barry J.', 'born': '1951-09-30'}
# {'firstname': 'J. Robin', 'born': '1937-06-11'}
# {'firstname': 'Roy J.', 'born': '1925-09-01'}
# {'firstname': 'John L.', 'born': '1934-08-21'}
# {'firstname': 'Theodor W.', 'born': '1941-10-30'}
# {'firstname': 'Yves', 'born': '1930-10-10'}
# {'firstname': 'Robert H.', 'born': '1942-02-27'}
# {'firstname': 'Richard R.', 'born': '1945-01-04'}
# {'firstname': 'International Atomic Energy Agency', 'born': '1957-00-00'}
# {'firstname': 'Mohamed', 'born': '1942-06-17'}
# {'firstname': 'Robert J.', 'born': '1930-06-08'}
# {'firstname': 'Thomas C.', 'born': '1921-04-14'}
# {'firstname': 'Harold', 'born': '1930-10-10'}
# {'firstname': 'Andrew Z.', 'born': '1959-04-27'}
# {'firstname': 'Craig C.', 'born': '1960-10-19'}
# {'firstname': 'John C.', 'born': '1946-08-07'}
# {'firstname': 'George F.', 'born': '1945-02-20'}
# {'firstname': 'Roger D.', 'born': '1947-04-24'}
# {'firstname': 'Edmund S.', 'born': '1933-07-26'}
# {'firstname': 'Orhan', 'born': '1952-06-07'}
# {'firstname': 'Muhammad', 'born': '1940-06-28'}
# {'firstname': 'Grameen Bank', 'born': '1976-00-00'}
# {'firstname': 'Mario R.', 'born': '1937-10-06'}
# {'firstname': 'Sir Martin J.', 'born': '1941-01-01'}
# {'firstname': 'Oliver', 'born': '1925-06-23'}
# {'firstname': 'Albert', 'born': '1938-03-07'}
# {'firstname': 'Peter', 'born': '1939-05-18'}
# {'firstname': 'Gerhard', 'born': '1936-10-10'}
# {'firstname': 'Doris', 'born': '1919-10-22'}
# {'firstname': 'Intergovernmental Panel on Climate Change', 'born': '1988-00-00'}
# {'firstname': 'Al', 'born': '1948-03-31'}
# {'firstname': 'Leonid', 'born': '1917-08-21'}
# {'firstname': 'Eric S.', 'born': '1950-12-12'}
# {'firstname': 'Roger B.', 'born': '1951-03-29'}
# {'firstname': 'Harald', 'born': '1936-03-11'}
# {'firstname': 'Françoise', 'born': '1947-07-30'}
# {'firstname': 'Luc', 'born': '1932-08-18'}
# {'firstname': 'Yoichiro', 'born': '1921-01-18'}
# {'firstname': 'Makoto', 'born': '1944-04-07'}
# {'firstname': 'Toshihide', 'born': '1940-02-07'}
# {'firstname': 'Osamu', 'born': '1928-08-27'}
# {'firstname': 'Martin', 'born': '1947-01-15'}
# {'firstname': 'Roger Y.', 'born': '1952-02-01'}
# {'firstname': 'Jean-Marie Gustave', 'born': '1940-04-13'}
# {'firstname': 'Martti', 'born': '1937-06-23'}
# {'firstname': 'Paul', 'born': '1953-02-28'}
# {'firstname': 'Elizabeth H.', 'born': '1948-11-26'}
# {'firstname': 'Carol W.', 'born': '1961-04-15'}
# {'firstname': 'Jack W.', 'born': '1952-11-09'}
# {'firstname': 'Charles K.', 'born': '1933-11-04'}
# {'firstname': 'Willard S.', 'born': '1924-08-19'}
# {'firstname': 'George E.', 'born': '1930-05-10'}
# {'firstname': 'Venkatraman', 'born': '1952-00-00'}
# {'firstname': 'Thomas A.', 'born': '1940-08-23'}
# {'firstname': 'Ada E.', 'born': '1939-06-22'}
# {'firstname': 'Herta', 'born': '1953-08-17'}
# {'firstname': 'Barack', 'born': '1961-08-04'}
# {'firstname': 'Elinor', 'born': '1933-08-07'}
# {'firstname': 'Oliver E.', 'born': '1932-09-27'}
# {'firstname': 'Robert G.', 'born': '1925-09-27'}
# {'firstname': 'Andre', 'born': '1958-10-21'}
# {'firstname': 'Konstantin', 'born': '1974-08-23'}
# {'firstname': 'Richard F.', 'born': '1931-08-15'}
# {'firstname': 'Ei-ichi', 'born': '1935-07-14'}
# {'firstname': 'Akira', 'born': '1930-09-12'}
# {'firstname': 'Mario', 'born': '1936-03-28'}
# {'firstname': 'Xiaobo', 'born': '1955-12-28'}
# {'firstname': 'Peter A.', 'born': '1940-04-29'}
# {'firstname': 'Dale T.', 'born': '1939-02-02'}
# {'firstname': 'Christopher A.', 'born': '1948-02-20'}
# {'firstname': 'Bruce A.', 'born': '1957-12-29'}
# {'firstname': 'Jules A.', 'born': '1941-08-02'}
# {'firstname': 'Ralph M.', 'born': '1943-01-14'}
# {'firstname': 'Saul', 'born': '1959-00-00'}
# {'firstname': 'Brian P.', 'born': '1967-02-24'}
# {'firstname': 'Adam G.', 'born': '1969-12-16'}
# {'firstname': 'Dan', 'born': '1941-01-24'}
# {'firstname': 'Tomas', 'born': '1931-04-15'}
# {'firstname': 'Ellen', 'born': '1938-10-29'}
# {'firstname': 'Leymah', 'born': '1972-02-01'}
# {'firstname': 'Tawakkol', 'born': '1979-02-07'}
# {'firstname': 'Thomas J.', 'born': '1943-07-19'}
# {'firstname': 'Christopher A.', 'born': '1942-10-21'}
# {'firstname': 'Sir John B.', 'born': '1933-10-02'}
# {'firstname': 'Shinya', 'born': '1962-09-04'}
# {'firstname': 'Serge', 'born': '1944-09-11'}
# {'firstname': 'David J.', 'born': '1944-02-24'}
# {'firstname': 'Robert J.', 'born': '1943-04-15'}
# {'firstname': 'Brian', 'born': '1955-05-30'}
# {'firstname': 'Mo', 'born': '1955-02-02'}
# {'firstname': 'European Union', 'born': '1952-00-00'}
# {'firstname': 'Alvin E.', 'born': '1951-12-18'}
# {'firstname': 'Lloyd S.', 'born': '1923-06-02'}
# {'firstname': 'James E.', 'born': '1950-11-03'}
# {'firstname': 'Randy W.', 'born': '1948-12-30'}
# {'firstname': 'Thomas C.', 'born': '1955-12-22'}
# {'firstname': 'François', 'born': '1932-11-06'}
# {'firstname': 'Peter', 'born': '1929-05-29'}
# {'firstname': 'Martin', 'born': '1930-03-15'}
# {'firstname': 'Michael', 'born': '1947-05-09'}
# {'firstname': 'Arieh', 'born': '1940-11-20'}
# {'firstname': 'Alice', 'born': '1931-07-10'}
# {'firstname': 'Organisation for the Prohibition of Chemical Weapons', 'born': '1997-00-00'}
# {'firstname': 'Eugene F.', 'born': '1939-02-14'}
# {'firstname': 'Lars Peter', 'born': '1952-10-26'}
# {'firstname': 'Robert J.', 'born': '1946-03-29'}
# {'firstname': 'John', 'born': '1939-11-18'}
# {'firstname': 'May-Britt', 'born': '1963-01-04'}
# {'firstname': 'Edvard I.', 'born': '1962-04-27'}
# {'firstname': 'Isamu', 'born': '1929-01-30'}
# {'firstname': 'Hiroshi', 'born': '1960-09-11'}
# {'firstname': 'Shuji', 'born': '1954-05-22'}
# {'firstname': 'Eric', 'born': '1960-01-13'}
# {'firstname': 'Stefan W.', 'born': '1962-12-23'}
# {'firstname': 'William E.', 'born': '1953-06-24'}
# {'firstname': 'Patrick', 'born': '1945-07-30'}
# {'firstname': 'Kailash', 'born': '1954-01-11'}
# {'firstname': 'Malala', 'born': '1997-07-12'}
# {'firstname': 'Jean', 'born': '1953-08-09'}
# {'firstname': 'William C.', 'born': '1930-06-28'}
# {'firstname': 'Satoshi', 'born': '1935-07-12'}
# {'firstname': 'Youyou', 'born': '1930-12-30'}
# {'firstname': 'Takaaki', 'born': '1959-03-09'}
# {'firstname': 'Arthur B.', 'born': '1943-08-29'}
# {'firstname': 'Tomas', 'born': '1938-01-28'}
# {'firstname': 'Paul', 'born': '1946-06-13'}
# {'firstname': 'Aziz', 'born': '1946-09-08'}
# {'firstname': 'Svetlana', 'born': '1948-05-31'}
# {'firstname': 'National Dialogue Quartet'}
# {'firstname': 'Angus', 'born': '1945-10-19'}
# {'firstname': 'Yoshinori', 'born': '1945-02-09'}
# {'firstname': 'David J.', 'born': '1934-09-21'}
# {'firstname': 'F. Duncan M.', 'born': '1951-09-14'}
# {'firstname': 'J. Michael', 'born': '1943-06-22'}
# {'firstname': 'Jean-Pierre', 'born': '1944-10-21'}
# {'firstname': 'Sir J. Fraser', 'born': '1942-05-24'}
# {'firstname': 'Bernard L.', 'born': '1951-05-18'}
# {'firstname': 'Juan Manuel', 'born': '1951-08-10'}
# {'firstname': 'Oliver', 'born': '1948-10-09'}
# {'firstname': 'Bengt', 'born': '1949-04-18'}
# {'firstname': 'Bob', 'born': '1941-05-24'}
# {'firstname': 'Jeffrey C.', 'born': '1945-05-03'}
# {'firstname': 'Michael', 'born': '1944-03-07'}
# {'firstname': 'Michael W.', 'born': '1949-03-28'}
# {'firstname': 'Rainer', 'born': '1932-09-29'}
# {'firstname': 'Barry C.', 'born': '1936-01-27'}
# {'firstname': 'Kip S.', 'born': '1940-06-01'}
# {'firstname': 'Jacques', 'born': '1942-06-08'}
# {'firstname': 'Joachim', 'born': '1940-09-12'}
# {'firstname': 'Richard', 'born': '1945-07-19'}
# {'firstname': 'Kazuo', 'born': '1954-11-08'}
# {'firstname': 'International Campaign to Abolish Nuclear Weapons', 'born': '2007-00-00'}
# {'firstname': 'Richard H.', 'born': '1945-09-12'}
# {'firstname': 'James P.', 'born': '1948-08-07'}
# {'firstname': 'Tasuku', 'born': '1942-01-27'}
# {'firstname': 'Arthur', 'born': '1922-09-02'}
# {'firstname': 'Gérard', 'born': '1944-06-22'}
# {'firstname': 'Donna', 'born': '1959-05-27'}
# {'firstname': 'Frances H.', 'born': '1956-07-25'}
# {'firstname': 'George P.', 'born': '1941-03-10'}
# {'firstname': 'Sir Gregory P.', 'born': '1951-04-14'}
# {'firstname': 'Denis', 'born': '1955-03-01'}
# {'firstname': 'Nadia', 'born': '1993-00-00'}
# {'firstname': 'William D.', 'born': '1941-05-31'}
# {'firstname': 'Paul M.', 'born': '1955-00-00'}
# {'firstname': 'William', 'born': '1957-11-23'}
# {'firstname': 'Peter', 'born': '1954-05-14'}
# {'firstname': 'Gregg', 'born': '1956-07-12'}
# {'firstname': 'James', 'born': '1935-04-25'}
# {'firstname': 'Michel', 'born': '1942-01-12'}
# {'firstname': 'Didier', 'born': '1966-02-23'}
# {'firstname': 'John', 'born': '1922-07-25'}
# {'firstname': 'M. Stanley', 'born': '1941-12-22'}
# {'firstname': 'Akira', 'born': '1948-01-30'}
# {'firstname': 'Olga', 'born': '1962-01-29'}
# {'firstname': 'Peter', 'born': '1942-12-06'}
# {'firstname': 'Abiy', 'born': '1976-08-15'}
# {'firstname': 'Abhijit', 'born': '1961-02-21'}
# {'firstname': 'Esther', 'born': '1972-10-25'}
# {'firstname': 'Michael', 'born': '1964-11-12'}
# {'firstname': 'Harvey', 'born': '1935-09-12'}
# {'firstname': 'Michael'}
# {'firstname': 'Charles', 'born': '1952-08-25'}
# {'firstname': 'Roger', 'born': '1931-08-08'}
# {'firstname': 'Reinhard', 'born': '1952-03-24'}
# {'firstname': 'Andrea', 'born': '1965-06-16'}
# {'firstname': 'Emmanuelle', 'born': '1968-12-11'}
# {'firstname': 'Jennifer A.', 'born': '1964-02-19'}
# {'firstname': 'Louise', 'born': '1943-04-22'}
# {'firstname': 'World Food Programme', 'born': '1961-00-00'}
# {'firstname': 'Paul', 'born': '1948-04-20'}
# {'firstname': 'Robert', 'born': '1937-05-16'}
# {'firstname': 'David', 'born': '1955-11-04'}
# {'firstname': 'Ardem', 'born': '1967-00-00'}
# {'firstname': 'Syukuro', 'born': '1931-09-21'}
# {'firstname': 'Klaus', 'born': '1931-10-25'}
# {'firstname': 'Giorgio', 'born': '1948-08-04'}
# {'firstname': 'Benjamin', 'born': '1968-01-11'}
# {'firstname': 'David', 'born': '1968-00-00'}
# {'firstname': 'Abdulrazak', 'born': '1948-00-00'}
# {'firstname': 'Maria', 'born': '1963-10-02'}
# {'firstname': 'Dmitry', 'born': '1961-00-00'}
# {'firstname': 'David', 'born': '1956-00-00'}
# {'firstname': 'Joshua', 'born': '1960-00-00'}
# {'firstname': 'Guido', 'born': '1963-09-03'}

# %%
#This example will exclude "address" from the result:
for x in nobel_data.find({},{ "bornCity": 0 }):
  pprint(x)
# Out:
# {'_id': ObjectId('61fd96d54039d142fbd0d691'),
#  'born': '1845-03-27',
#  'bornCountry': 'Prussia (now Germany)',
#  'bornCountryCode': 'DE',
#  'died': '1923-02-10',
#  'diedCity': 'Munich',
#  'diedCountry': 'Germany',
#  'diedCountryCode': 'DE',
#  'firstname': 'Wilhelm Conrad',
#  'gender': 'male',
#  'id': '1',
#  'prizes': [{'affiliations': [{'city': 'Munich',
#                                'country': 'Germany',
#                                'name': 'Munich University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services he '
#                            'has rendered by the discovery of the remarkable '
#                            'rays subsequently named after him"',
#              'share': '1',
#              'year': '1901'}],
#  'surname': 'Röntgen'}
# {'_id': ObjectId('61fd96d54039d142fbd0d692'),
#  'born': '1853-07-18',
#  'bornCountry': 'the Netherlands',
#  'bornCountryCode': 'NL',
#  'died': '1928-02-04',
#  'diedCountry': 'the Netherlands',
#  'diedCountryCode': 'NL',
#  'firstname': 'Hendrik A.',
#  'gender': 'male',
#  'id': '2',
#  'prizes': [{'affiliations': [{'city': 'Leiden',
#                                'country': 'the Netherlands',
#                                'name': 'Leiden University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary service they '
#                            'rendered by their researches into the influence of '
#                            'magnetism upon radiation phenomena"',
#              'share': '2',
#              'year': '1902'}],
#  'surname': 'Lorentz'}
# {'_id': ObjectId('61fd96d54039d142fbd0d693'),
#  'born': '1865-05-25',
#  'bornCountry': 'the Netherlands',
#  'bornCountryCode': 'NL',
#  'died': '1943-10-09',
#  'diedCity': 'Amsterdam',
#  'diedCountry': 'the Netherlands',
#  'diedCountryCode': 'NL',
#  'firstname': 'Pieter',
#  'gender': 'male',
#  'id': '3',
#  'prizes': [{'affiliations': [{'city': 'Amsterdam',
#                                'country': 'the Netherlands',
#                                'name': 'Amsterdam University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary service they '
#                            'rendered by their researches into the influence of '
#                            'magnetism upon radiation phenomena"',
#              'share': '2',
#              'year': '1902'}],
#  'surname': 'Zeeman'}
# {'_id': ObjectId('61fd96d54039d142fbd0d694'),
#  'born': '1852-12-15',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '1908-08-25',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Henri',
#  'gender': 'male',
#  'id': '4',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'École Polytechnique'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services he '
#                            'has rendered by his discovery of spontaneous '
#                            'radioactivity"',
#              'share': '2',
#              'year': '1903'}],
#  'surname': 'Becquerel'}
# {'_id': ObjectId('61fd96d54039d142fbd0d695'),
#  'born': '1859-05-15',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '1906-04-19',
#  'diedCity': 'Paris',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Pierre',
#  'gender': 'male',
#  'id': '5',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'École municipale de physique et de '
#                                        'chimie industrielles (Municipal School '
#                                        'of Industrial Physics and Chemistry)'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services they '
#                            'have rendered by their joint researches on the '
#                            'radiation phenomena discovered by Professor Henri '
#                            'Becquerel"',
#              'share': '4',
#              'year': '1903'}],
#  'surname': 'Curie'}
# {'_id': ObjectId('61fd96d54039d142fbd0d696'),
#  'born': '1867-11-07',
#  'bornCountry': 'Russian Empire (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1934-07-04',
#  'diedCity': 'Sallanches',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Marie',
#  'gender': 'female',
#  'id': '6',
#  'prizes': [{'affiliations': [[]],
#              'category': 'physics',
#              'motivation': '"in recognition of the extraordinary services they '
#                            'have rendered by their joint researches on the '
#                            'radiation phenomena discovered by Professor Henri '
#                            'Becquerel"',
#              'share': '4',
#              'year': '1903'},
#             {'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Sorbonne University'}],
#              'category': 'chemistry',
#              'motivation': '"in recognition of her services to the advancement '
#                            'of chemistry by the discovery of the elements '
#                            'radium and polonium, by the isolation of radium '
#                            'and the study of the nature and compounds of this '
#                            'remarkable element"',
#              'share': '1',
#              'year': '1911'}],
#  'surname': 'Curie'}
# {'_id': ObjectId('61fd96d54039d142fbd0d697'),
#  'born': '1842-11-12',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1919-06-30',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'Lord',
#  'gender': 'male',
#  'id': '8',
#  'prizes': [{'affiliations': [{'city': 'London',
#                                'country': 'United Kingdom',
#                                'name': 'Royal Institution of Great Britain'}],
#              'category': 'physics',
#              'motivation': '"for his investigations of the densities of the '
#                            'most important gases and for his discovery of '
#                            'argon in connection with these studies"',
#              'share': '1',
#              'year': '1904'}],
#  'surname': 'Rayleigh'}
# {'_id': ObjectId('61fd96d54039d142fbd0d698'),
#  'born': '1862-06-07',
#  'bornCountry': 'Hungary (now Slovakia)',
#  'bornCountryCode': 'SK',
#  'died': '1947-05-20',
#  'diedCity': 'Messelhausen',
#  'diedCountry': 'Germany',
#  'diedCountryCode': 'DE',
#  'firstname': 'Philipp',
#  'gender': 'male',
#  'id': '9',
#  'prizes': [{'affiliations': [{'city': 'Kiel',
#                                'country': 'Germany',
#                                'name': 'Kiel University'}],
#              'category': 'physics',
#              'motivation': '"for his work on cathode rays"',
#              'share': '1',
#              'year': '1905'}],
#  'surname': 'Lenard'}
# {'_id': ObjectId('61fd96d54039d142fbd0d699'),
#  'born': '1856-12-18',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1940-08-30',
#  'diedCity': 'Cambridge',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'J.J.',
#  'gender': 'male',
#  'id': '10',
#  'prizes': [{'affiliations': [{'city': 'Cambridge',
#                                'country': 'United Kingdom',
#                                'name': 'University of Cambridge'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the great merits of his '
#                            'theoretical and experimental investigations on the '
#                            'conduction of electricity by gases"',
#              'share': '1',
#              'year': '1906'}],
#  'surname': 'Thomson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d69a'),
#  'born': '1852-12-19',
#  'bornCountry': 'Prussia (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1931-05-09',
#  'diedCity': 'Pasadena, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Albert A.',
#  'gender': 'male',
#  'id': '11',
#  'prizes': [{'affiliations': [{'city': 'Chicago, IL',
#                                'country': 'USA',
#                                'name': 'University of Chicago'}],
#              'category': 'physics',
#              'motivation': '"for his optical precision instruments and the '
#                            'spectroscopic and metrological investigations '
#                            'carried out with their aid"',
#              'share': '1',
#              'year': '1907'}],
#  'surname': 'Michelson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d69b'),
#  'born': '1845-08-16',
#  'bornCountry': 'Luxembourg',
#  'bornCountryCode': 'LU',
#  'died': '1921-07-13',
#  'firstname': 'Gabriel',
#  'gender': 'male',
#  'id': '12',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Sorbonne University'}],
#              'category': 'physics',
#              'motivation': '"for his method of reproducing colours '
#                            'photographically based on the phenomenon of '
#                            'interference"',
#              'share': '1',
#              'year': '1908'}],
#  'surname': 'Lippmann'}
# {'_id': ObjectId('61fd96d54039d142fbd0d69c'),
#  'born': '1874-04-25',
#  'bornCountry': 'Italy',
#  'bornCountryCode': 'IT',
#  'died': '1937-07-20',
#  'diedCity': 'Rome',
#  'diedCountry': 'Italy',
#  'diedCountryCode': 'IT',
#  'firstname': 'Guglielmo',
#  'gender': 'male',
#  'id': '13',
#  'prizes': [{'affiliations': [{'city': 'London',
#                                'country': 'United Kingdom',
#                                'name': 'Marconi Wireless Telegraph Co. Ltd.'}],
#              'category': 'physics',
#              'motivation': '"in recognition of their contributions to the '
#                            'development of wireless telegraphy"',
#              'share': '2',
#              'year': '1909'}],
#  'surname': 'Marconi'}
# {'_id': ObjectId('61fd96d54039d142fbd0d69d'),
#  'born': '1850-06-06',
#  'bornCountry': 'Hesse-Kassel (now Germany)',
#  'bornCountryCode': 'DE',
#  'died': '1918-04-20',
#  'diedCity': 'Brooklyn, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Ferdinand',
#  'gender': 'male',
#  'id': '14',
#  'prizes': [{'affiliations': [{'city': 'Strasbourg',
#                                'country': 'Germany (now France)',
#                                'name': 'Strasbourg University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of their contributions to the '
#                            'development of wireless telegraphy"',
#              'share': '2',
#              'year': '1909'}],
#  'surname': 'Braun'}
# {'_id': ObjectId('61fd96d54039d142fbd0d69e'),
#  'born': '1837-11-23',
#  'bornCountry': 'the Netherlands',
#  'bornCountryCode': 'NL',
#  'died': '1923-03-08',
#  'diedCity': 'Amsterdam',
#  'diedCountry': 'the Netherlands',
#  'diedCountryCode': 'NL',
#  'firstname': 'Johannes Diderik',
#  'gender': 'male',
#  'id': '15',
#  'prizes': [{'affiliations': [{'city': 'Amsterdam',
#                                'country': 'the Netherlands',
#                                'name': 'Amsterdam University'}],
#              'category': 'physics',
#              'motivation': '"for his work on the equation of state for gases '
#                            'and liquids"',
#              'share': '1',
#              'year': '1910'}],
#  'surname': 'van der Waals'}
# {'_id': ObjectId('61fd96d54039d142fbd0d69f'),
#  'born': '1864-01-13',
#  'bornCountry': 'Prussia (now Russia)',
#  'bornCountryCode': 'RU',
#  'died': '1928-08-30',
#  'diedCity': 'Munich',
#  'diedCountry': 'Germany',
#  'diedCountryCode': 'DE',
#  'firstname': 'Wilhelm',
#  'gender': 'male',
#  'id': '16',
#  'prizes': [{'affiliations': [{'city': 'Würzburg',
#                                'country': 'Germany',
#                                'name': 'Würzburg University'}],
#              'category': 'physics',
#              'motivation': '"for his discoveries regarding the laws governing '
#                            'the radiation of heat"',
#              'share': '1',
#              'year': '1911'}],
#  'surname': 'Wien'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a0'),
#  'born': '1869-11-30',
#  'bornCountry': 'Sweden',
#  'bornCountryCode': 'SE',
#  'died': '1937-12-09',
#  'diedCity': 'Stockholm',
#  'diedCountry': 'Sweden',
#  'diedCountryCode': 'SE',
#  'firstname': 'Gustaf',
#  'gender': 'male',
#  'id': '17',
#  'prizes': [{'affiliations': [{'city': 'Lidingö, Stockholm',
#                                'country': 'Sweden',
#                                'name': 'Swedish Gas-Accumulator Co.'}],
#              'category': 'physics',
#              'motivation': '"for his invention of automatic regulators for use '
#                            'in conjunction with gas accumulators for '
#                            'illuminating lighthouses and buoys"',
#              'share': '1',
#              'year': '1912'}],
#  'surname': 'Dalén'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a1'),
#  'born': '1853-09-21',
#  'bornCountry': 'the Netherlands',
#  'bornCountryCode': 'NL',
#  'died': '1926-02-21',
#  'diedCity': 'Leiden',
#  'diedCountry': 'the Netherlands',
#  'diedCountryCode': 'NL',
#  'firstname': 'Heike',
#  'gender': 'male',
#  'id': '18',
#  'prizes': [{'affiliations': [{'city': 'Leiden',
#                                'country': 'the Netherlands',
#                                'name': 'Leiden University'}],
#              'category': 'physics',
#              'motivation': '"for his investigations on the properties of '
#                            'matter at low temperatures which led, inter alia, '
#                            'to the production of liquid helium"',
#              'share': '1',
#              'year': '1913'}],
#  'surname': 'Kamerlingh Onnes'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a2'),
#  'born': '1879-10-09',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1960-04-23',
#  'diedCity': 'Berlin',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Max',
#  'gender': 'male',
#  'id': '19',
#  'prizes': [{'affiliations': [{'city': 'Frankfurt-on-the-Main',
#                                'country': 'Germany',
#                                'name': 'Frankfurt-on-the-Main University'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of the diffraction of X-rays by '
#                            'crystals"',
#              'share': '1',
#              'year': '1914'}],
#  'surname': 'von Laue'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a3'),
#  'born': '1862-07-02',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1942-03-12',
#  'diedCity': 'London',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'William',
#  'gender': 'male',
#  'id': '20',
#  'prizes': [{'affiliations': [{'city': 'London',
#                                'country': 'United Kingdom',
#                                'name': 'University College'}],
#              'category': 'physics',
#              'motivation': '"for their services in the analysis of crystal '
#                            'structure by means of X-rays"',
#              'share': '2',
#              'year': '1915'}],
#  'surname': 'Bragg'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a4'),
#  'born': '1890-03-31',
#  'bornCountry': 'Australia',
#  'bornCountryCode': 'AU',
#  'died': '1971-07-01',
#  'diedCity': 'Ipswich',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'Lawrence',
#  'gender': 'male',
#  'id': '21',
#  'prizes': [{'affiliations': [{'city': 'Manchester',
#                                'country': 'United Kingdom',
#                                'name': 'Victoria University'}],
#              'category': 'physics',
#              'motivation': '"for their services in the analysis of crystal '
#                            'structure by means of X-rays"',
#              'share': '2',
#              'year': '1915'}],
#  'surname': 'Bragg'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a5'),
#  'born': '1877-06-07',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1944-10-23',
#  'diedCity': 'Edinburgh',
#  'diedCountry': 'Scotland',
#  'diedCountryCode': 'GB',
#  'firstname': 'Charles Glover',
#  'gender': 'male',
#  'id': '22',
#  'prizes': [{'affiliations': [{'city': 'Edinburgh',
#                                'country': 'United Kingdom',
#                                'name': 'Edinburgh University'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of the characteristic '
#                            'R&ouml;ntgen radiation of the elements"',
#              'share': '1',
#              'year': '1917'}],
#  'surname': 'Barkla'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a6'),
#  'born': '1858-04-23',
#  'bornCountry': 'Schleswig (now Germany)',
#  'bornCountryCode': 'DE',
#  'died': '1947-10-04',
#  'diedCity': 'Göttingen',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Max',
#  'gender': 'male',
#  'id': '23',
#  'prizes': [{'affiliations': [{'city': 'Berlin',
#                                'country': 'Germany',
#                                'name': 'Berlin University'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the services he rendered to the '
#                            'advancement of Physics by his discovery of energy '
#                            'quanta"',
#              'share': '1',
#              'year': '1918'}],
#  'surname': 'Planck'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a7'),
#  'born': '1874-04-15',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1957-06-21',
#  'diedCity': 'Traunstein',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Johannes',
#  'gender': 'male',
#  'id': '24',
#  'prizes': [{'affiliations': [{'city': 'Greifswald',
#                                'country': 'Germany',
#                                'name': 'Greifswald University'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of the Doppler effect in canal '
#                            'rays and the splitting of spectral lines in '
#                            'electric fields"',
#              'share': '1',
#              'year': '1919'}],
#  'surname': 'Stark'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a8'),
#  'born': '1861-02-15',
#  'bornCountry': 'Switzerland',
#  'bornCountryCode': 'CH',
#  'died': '1938-06-13',
#  'diedCity': 'Sèvres',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Charles Edouard',
#  'gender': 'male',
#  'id': '25',
#  'prizes': [{'affiliations': [{'city': 'Sèvres',
#                                'country': 'France',
#                                'name': 'Bureau International des Poids et '
#                                        'Mesures (International Bureau of '
#                                        'Weights and Measures)'}],
#              'category': 'physics',
#              'motivation': '"in recognition of the service he has rendered to '
#                            'precision measurements in Physics by his discovery '
#                            'of anomalies in nickel steel alloys"',
#              'share': '1',
#              'year': '1920'}],
#  'surname': 'Guillaume'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6a9'),
#  'born': '1879-03-14',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1955-04-18',
#  'diedCity': 'Princeton, NJ',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Albert',
#  'gender': 'male',
#  'id': '26',
#  'prizes': [{'affiliations': [{'city': 'Berlin',
#                                'country': 'Germany',
#                                'name': 'Kaiser-Wilhelm-Institut (now '
#                                        'Max-Planck-Institut) für Physik'}],
#              'category': 'physics',
#              'motivation': '"for his services to Theoretical Physics, and '
#                            'especially for his discovery of the law of the '
#                            'photoelectric effect"',
#              'share': '1',
#              'year': '1921'}],
#  'surname': 'Einstein'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6aa'),
#  'born': '1885-10-07',
#  'bornCountry': 'Denmark',
#  'bornCountryCode': 'DK',
#  'died': '1962-11-18',
#  'diedCity': 'Copenhagen',
#  'diedCountry': 'Denmark',
#  'diedCountryCode': 'DK',
#  'firstname': 'Niels',
#  'gender': 'male',
#  'id': '27',
#  'prizes': [{'affiliations': [{'city': 'Copenhagen',
#                                'country': 'Denmark',
#                                'name': 'Copenhagen University'}],
#              'category': 'physics',
#              'motivation': '"for his services in the investigation of the '
#                            'structure of atoms and of the radiation emanating '
#                            'from them"',
#              'share': '1',
#              'year': '1922'}],
#  'surname': 'Bohr'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ab'),
#  'born': '1868-03-22',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1953-12-19',
#  'diedCity': 'San Marino, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Robert A.',
#  'gender': 'male',
#  'id': '28',
#  'prizes': [{'affiliations': [{'city': 'Pasadena, CA',
#                                'country': 'USA',
#                                'name': 'California Institute of Technology '
#                                        '(Caltech)'}],
#              'category': 'physics',
#              'motivation': '"for his work on the elementary charge of '
#                            'electricity and on the photoelectric effect"',
#              'share': '1',
#              'year': '1923'}],
#  'surname': 'Millikan'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ac'),
#  'born': '1886-12-03',
#  'bornCountry': 'Sweden',
#  'bornCountryCode': 'SE',
#  'died': '1978-09-26',
#  'diedCity': 'Stockholm',
#  'diedCountry': 'Sweden',
#  'diedCountryCode': 'SE',
#  'firstname': 'Manne',
#  'gender': 'male',
#  'id': '29',
#  'prizes': [{'affiliations': [{'city': 'Uppsala',
#                                'country': 'Sweden',
#                                'name': 'Uppsala University'}],
#              'category': 'physics',
#              'motivation': '"for his discoveries and research in the field of '
#                            'X-ray spectroscopy"',
#              'share': '1',
#              'year': '1924'}],
#  'surname': 'Siegbahn'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ad'),
#  'born': '1882-08-26',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1964-05-21',
#  'diedCity': 'Göttingen',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'James',
#  'gender': 'male',
#  'id': '30',
#  'prizes': [{'affiliations': [{'city': 'Göttingen',
#                                'country': 'Germany',
#                                'name': 'Goettingen University'}],
#              'category': 'physics',
#              'motivation': '"for their discovery of the laws governing the '
#                            'impact of an electron upon an atom"',
#              'share': '2',
#              'year': '1925'}],
#  'surname': 'Franck'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ae'),
#  'born': '1887-07-22',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1975-10-30',
#  'diedCity': 'Berlin',
#  'diedCountry': 'East Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Gustav',
#  'gender': 'male',
#  'id': '31',
#  'prizes': [{'affiliations': [{'city': 'Halle',
#                                'country': 'Germany',
#                                'name': 'Halle University'}],
#              'category': 'physics',
#              'motivation': '"for their discovery of the laws governing the '
#                            'impact of an electron upon an atom"',
#              'share': '2',
#              'year': '1925'}],
#  'surname': 'Hertz'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6af'),
#  'born': '1870-09-30',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '1942-04-17',
#  'diedCity': 'New York, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Jean Baptiste',
#  'gender': 'male',
#  'id': '32',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Sorbonne University'}],
#              'category': 'physics',
#              'motivation': '"for his work on the discontinuous structure of '
#                            'matter, and especially for his discovery of '
#                            'sedimentation equilibrium"',
#              'share': '1',
#              'year': '1926'}],
#  'surname': 'Perrin'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b0'),
#  'born': '1892-09-10',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1962-03-15',
#  'diedCity': 'Berkeley, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Arthur H.',
#  'gender': 'male',
#  'id': '33',
#  'prizes': [{'affiliations': [{'city': 'Chicago, IL',
#                                'country': 'USA',
#                                'name': 'University of Chicago'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of the effect named after him"',
#              'share': '2',
#              'year': '1927'}],
#  'surname': 'Compton'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b1'),
#  'born': '1869-02-14',
#  'bornCountry': 'Scotland',
#  'bornCountryCode': 'GB',
#  'died': '1959-11-15',
#  'diedCity': 'Carlops',
#  'diedCountry': 'Scotland',
#  'diedCountryCode': 'GB',
#  'firstname': 'C.T.R.',
#  'gender': 'male',
#  'id': '34',
#  'prizes': [{'affiliations': [{'city': 'Cambridge',
#                                'country': 'United Kingdom',
#                                'name': 'University of Cambridge'}],
#              'category': 'physics',
#              'motivation': '"for his method of making the paths of '
#                            'electrically charged particles visible by '
#                            'condensation of vapour"',
#              'share': '2',
#              'year': '1927'}],
#  'surname': 'Wilson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b2'),
#  'born': '1879-04-26',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1959-02-15',
#  'diedCity': 'Alton',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'Owen Willans',
#  'gender': 'male',
#  'id': '35',
#  'prizes': [{'affiliations': [{'city': 'London',
#                                'country': 'United Kingdom',
#                                'name': 'London University'}],
#              'category': 'physics',
#              'motivation': '"for his work on the thermionic phenomenon and '
#                            'especially for the discovery of the law named '
#                            'after him"',
#              'share': '1',
#              'year': '1928'}],
#  'surname': 'Richardson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b3'),
#  'born': '1892-08-15',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '1987-03-19',
#  'diedCity': 'Paris',
#  'diedCountry': 'France',
#  'diedCountryCode': 'FR',
#  'firstname': 'Louis',
#  'gender': 'male',
#  'id': '36',
#  'prizes': [{'affiliations': [{'city': 'Paris',
#                                'country': 'France',
#                                'name': 'Sorbonne University, Institut Henri '
#                                        'Poincaré'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of the wave nature of '
#                            'electrons"',
#              'share': '1',
#              'year': '1929'}],
#  'surname': 'de Broglie'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b4'),
#  'born': '1888-11-07',
#  'bornCountry': 'India',
#  'bornCountryCode': 'IN',
#  'died': '1970-11-21',
#  'diedCity': 'Bangalore',
#  'diedCountry': 'India',
#  'diedCountryCode': 'IN',
#  'firstname': 'Sir Chandrasekhara Venkata',
#  'gender': 'male',
#  'id': '37',
#  'prizes': [{'affiliations': [{'city': 'Calcutta',
#                                'country': 'India',
#                                'name': 'Calcutta University'}],
#              'category': 'physics',
#              'motivation': '"for his work on the scattering of light and for '
#                            'the discovery of the effect named after him"',
#              'share': '1',
#              'year': '1930'}],
#  'surname': 'Raman'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b5'),
#  'born': '1901-12-05',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1976-02-01',
#  'diedCity': 'Munich',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Werner',
#  'gender': 'male',
#  'id': '38',
#  'prizes': [{'affiliations': [{'city': 'Leipzig',
#                                'country': 'Germany',
#                                'name': 'Leipzig University'}],
#              'category': 'physics',
#              'motivation': '"for the creation of quantum mechanics, the '
#                            'application of which has, inter alia, led to the '
#                            'discovery of the allotropic forms of hydrogen"',
#              'share': '1',
#              'year': '1932'}],
#  'surname': 'Heisenberg'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b6'),
#  'born': '1887-08-12',
#  'bornCountry': 'Austria',
#  'bornCountryCode': 'AT',
#  'died': '1961-01-04',
#  'diedCity': 'Vienna',
#  'diedCountry': 'Austria',
#  'diedCountryCode': 'AT',
#  'firstname': 'Erwin',
#  'gender': 'male',
#  'id': '39',
#  'prizes': [{'affiliations': [{'city': 'Berlin',
#                                'country': 'Germany',
#                                'name': 'Berlin University'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of new productive forms of '
#                            'atomic theory"',
#              'share': '2',
#              'year': '1933'}],
#  'surname': 'Schrödinger'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b7'),
#  'born': '1902-08-08',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1984-10-20',
#  'diedCity': 'Tallahassee, FL',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Paul A.M.',
#  'gender': 'male',
#  'id': '40',
#  'prizes': [{'affiliations': [{'city': 'Cambridge',
#                                'country': 'United Kingdom',
#                                'name': 'University of Cambridge'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of new productive forms of '
#                            'atomic theory"',
#              'share': '2',
#              'year': '1933'}],
#  'surname': 'Dirac'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b8'),
#  'born': '1891-10-20',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1974-07-24',
#  'diedCity': 'Cambridge',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'James',
#  'gender': 'male',
#  'id': '41',
#  'prizes': [{'affiliations': [{'city': 'Liverpool',
#                                'country': 'United Kingdom',
#                                'name': 'Liverpool University'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of the neutron"',
#              'share': '1',
#              'year': '1935'}],
#  'surname': 'Chadwick'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6b9'),
#  'born': '1883-06-24',
#  'bornCountry': 'Austria',
#  'bornCountryCode': 'AT',
#  'died': '1964-12-17',
#  'diedCity': 'Mount Vernon, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Victor F.',
#  'gender': 'male',
#  'id': '42',
#  'prizes': [{'affiliations': [{'city': 'Innsbruck',
#                                'country': 'Austria',
#                                'name': 'Innsbruck University'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of cosmic radiation"',
#              'share': '2',
#              'year': '1936'}],
#  'surname': 'Hess'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ba'),
#  'born': '1905-09-03',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1991-01-11',
#  'diedCity': 'San Marino, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Carl D.',
#  'gender': 'male',
#  'id': '43',
#  'prizes': [{'affiliations': [{'city': 'Pasadena, CA',
#                                'country': 'USA',
#                                'name': 'California Institute of Technology '
#                                        '(Caltech)'}],
#              'category': 'physics',
#              'motivation': '"for his discovery of the positron"',
#              'share': '2',
#              'year': '1936'}],
#  'surname': 'Anderson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6bb'),
#  'born': '1881-10-22',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1958-02-01',
#  'diedCity': 'Charlottesville, VA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Clinton',
#  'gender': 'male',
#  'id': '44',
#  'prizes': [{'affiliations': [{'city': 'New York, NY',
#                                'country': 'USA',
#                                'name': 'Bell Telephone Laboratories'}],
#              'category': 'physics',
#              'motivation': '"for their experimental discovery of the '
#                            'diffraction of electrons by crystals"',
#              'share': '2',
#              'year': '1937'}],
#  'surname': 'Davisson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6bc'),
#  'born': '1892-05-03',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1975-09-10',
#  'diedCity': 'Cambridge',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'George Paget',
#  'gender': 'male',
#  'id': '45',
#  'prizes': [{'affiliations': [{'city': 'London',
#                                'country': 'United Kingdom',
#                                'name': 'London University'}],
#              'category': 'physics',
#              'motivation': '"for their experimental discovery of the '
#                            'diffraction of electrons by crystals"',
#              'share': '2',
#              'year': '1937'}],
#  'surname': 'Thomson'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6bd'),
#  'born': '1901-09-29',
#  'bornCountry': 'Italy',
#  'bornCountryCode': 'IT',
#  'died': '1954-11-28',
#  'diedCity': 'Chicago, IL',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Enrico',
#  'gender': 'male',
#  'id': '46',
#  'prizes': [{'affiliations': [{'city': 'Rome',
#                                'country': 'Italy',
#                                'name': 'Rome University'}],
#              'category': 'physics',
#              'motivation': '"for his demonstrations of the existence of new '
#                            'radioactive elements produced by neutron '
#                            'irradiation, and for his related discovery of '
#                            'nuclear reactions brought about by slow neutrons"',
#              'share': '1',
#              'year': '1938'}],
#  'surname': 'Fermi'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6be'),
#  'born': '1901-08-08',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1958-08-27',
#  'diedCity': 'Palo Alto, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Ernest',
#  'gender': 'male',
#  'id': '47',
#  'prizes': [{'affiliations': [{'city': 'Berkeley, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'physics',
#              'motivation': '"for the invention and development of the '
#                            'cyclotron and for results obtained with it, '
#                            'especially with regard to artificial radioactive '
#                            'elements"',
#              'share': '1',
#              'year': '1939'}],
#  'surname': 'Lawrence'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6bf'),
#  'born': '1888-02-17',
#  'bornCountry': 'Germany (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1969-08-17',
#  'diedCity': 'Berkeley, CA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Otto',
#  'gender': 'male',
#  'id': '48',
#  'prizes': [{'affiliations': [{'city': 'Pittsburgh, PA',
#                                'country': 'USA',
#                                'name': 'Carnegie Institute of Technology'}],
#              'category': 'physics',
#              'motivation': '"for his contribution to the development of the '
#                            'molecular ray method and his discovery of the '
#                            'magnetic moment of the proton"',
#              'share': '1',
#              'year': '1943'}],
#  'surname': 'Stern'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c0'),
#  'born': '1898-07-29',
#  'bornCountry': 'Austria-Hungary (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1988-01-11',
#  'diedCity': 'New York, NY',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Isidor Isaac',
#  'gender': 'male',
#  'id': '49',
#  'prizes': [{'affiliations': [{'city': 'New York, NY',
#                                'country': 'USA',
#                                'name': 'Columbia University'}],
#              'category': 'physics',
#              'motivation': '"for his resonance method for recording the '
#                            'magnetic properties of atomic nuclei"',
#              'share': '1',
#              'year': '1944'}],
#  'surname': 'Rabi'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c1'),
#  'born': '1900-04-25',
#  'bornCountry': 'Austria',
#  'bornCountryCode': 'AT',
#  'died': '1958-12-15',
#  'diedCity': 'Zurich',
#  'diedCountry': 'Switzerland',
#  'diedCountryCode': 'CH',
#  'firstname': 'Wolfgang',
#  'gender': 'male',
#  'id': '50',
#  'prizes': [{'affiliations': [{'city': 'Princeton, NJ',
#                                'country': 'USA',
#                                'name': 'Princeton University'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of the Exclusion Principle, '
#                            'also called the Pauli Principle"',
#              'share': '1',
#              'year': '1945'}],
#  'surname': 'Pauli'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c2'),
#  'born': '1882-04-21',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1961-08-20',
#  'diedCity': 'Randolph, NH',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Percy W.',
#  'gender': 'male',
#  'id': '51',
#  'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#                                'country': 'USA',
#                                'name': 'Harvard University'}],
#              'category': 'physics',
#              'motivation': '"for the invention of an apparatus to produce '
#                            'extremely high pressures, and for the discoveries '
#                            'he made therewith in the field of high pressure '
#                            'physics"',
#              'share': '1',
#              'year': '1946'}],
#  'surname': 'Bridgman'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c3'),
#  'born': '1892-09-06',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1965-04-21',
#  'diedCity': 'Edinburgh',
#  'diedCountry': 'Scotland',
#  'diedCountryCode': 'GB',
#  'firstname': 'Edward V.',
#  'gender': 'male',
#  'id': '52',
#  'prizes': [{'affiliations': [{'city': 'London',
#                                'country': 'United Kingdom',
#                                'name': 'Department of Scientific and '
#                                        'Industrial Research'}],
#              'category': 'physics',
#              'motivation': '"for his investigations of the physics of the '
#                            'upper atmosphere especially for the discovery of '
#                            'the so-called Appleton layer"',
#              'share': '1',
#              'year': '1947'}],
#  'surname': 'Appleton'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c4'),
#  'born': '1897-11-18',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1974-07-13',
#  'diedCity': 'London',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'Patrick M.S.',
#  'gender': 'male',
#  'id': '53',
#  'prizes': [{'affiliations': [{'city': 'Manchester',
#                                'country': 'United Kingdom',
#                                'name': 'Victoria University'}],
#              'category': 'physics',
#              'motivation': '"for his development of the Wilson cloud chamber '
#                            'method, and his discoveries therewith in the '
#                            'fields of nuclear physics and cosmic radiation"',
#              'share': '1',
#              'year': '1948'}],
#  'surname': 'Blackett'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c5'),
#  'born': '1907-01-23',
#  'bornCountry': 'Japan',
#  'bornCountryCode': 'JP',
#  'died': '1981-09-08',
#  'diedCity': 'Kyoto',
#  'diedCountry': 'Japan',
#  'diedCountryCode': 'JP',
#  'firstname': 'Hideki',
#  'gender': 'male',
#  'id': '54',
#  'prizes': [{'affiliations': [{'city': 'Kyoto',
#                                'country': 'Japan',
#                                'name': 'Kyoto Imperial University'},
#                               {'city': 'New York, NY',
#                                'country': 'USA',
#                                'name': 'Columbia University'}],
#              'category': 'physics',
#              'motivation': '"for his prediction of the existence of mesons on '
#                            'the basis of theoretical work on nuclear forces"',
#              'share': '1',
#              'year': '1949'}],
#  'surname': 'Yukawa'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c6'),
#  'born': '1903-12-05',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1969-08-09',
#  'diedCountry': 'Italy',
#  'diedCountryCode': 'IT',
#  'firstname': 'Cecil',
#  'gender': 'male',
#  'id': '55',
#  'prizes': [{'affiliations': [{'city': 'Bristol',
#                                'country': 'United Kingdom',
#                                'name': 'Bristol University'}],
#              'category': 'physics',
#              'motivation': '"for his development of the photographic method of '
#                            'studying nuclear processes and his discoveries '
#                            'regarding mesons made with this method"',
#              'share': '1',
#              'year': '1950'}],
#  'surname': 'Powell'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c7'),
#  'born': '1897-05-27',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '1967-09-18',
#  'diedCity': 'Cambridge',
#  'diedCountry': 'United Kingdom',
#  'diedCountryCode': 'GB',
#  'firstname': 'John',
#  'gender': 'male',
#  'id': '56',
#  'prizes': [{'affiliations': [{'city': 'Harwell, Berkshire',
#                                'country': 'United Kingdom',
#                                'name': 'Atomic Energy Research Establishment'}],
#              'category': 'physics',
#              'motivation': '"for their pioneer work on the transmutation of '
#                            'atomic nuclei by artificially accelerated atomic '
#                            'particles"',
#              'share': '2',
#              'year': '1951'}],
#  'surname': 'Cockcroft'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c8'),
#  'born': '1903-10-06',
#  'bornCountry': 'Ireland',
#  'bornCountryCode': 'IE',
#  'died': '1995-06-25',
#  'diedCity': 'Belfast',
#  'diedCountry': 'Northern Ireland',
#  'diedCountryCode': 'GB',
#  'firstname': 'Ernest T.S.',
#  'gender': 'male',
#  'id': '57',
#  'prizes': [{'affiliations': [{'city': 'Dublin',
#                                'country': 'Ireland',
#                                'name': 'Trinity College'}],
#              'category': 'physics',
#              'motivation': '"for their pioneer work on the transmutation of '
#                            'atomic nuclei by artificially accelerated atomic '
#                            'particles"',
#              'share': '2',
#              'year': '1951'}],
#  'surname': 'Walton'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6c9'),
#  'born': '1905-10-23',
#  'bornCountry': 'Switzerland',
#  'bornCountryCode': 'CH',
#  'died': '1983-09-10',
#  'diedCity': 'Zurich',
#  'diedCountry': 'Switzerland',
#  'diedCountryCode': 'CH',
#  'firstname': 'Felix',
#  'gender': 'male',
#  'id': '58',
#  'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#                                'country': 'USA',
#                                'name': 'Stanford University'}],
#              'category': 'physics',
#              'motivation': '"for their development of new methods for nuclear '
#                            'magnetic precision measurements and discoveries in '
#                            'connection therewith"',
#              'share': '2',
#              'year': '1952'}],
#  'surname': 'Bloch'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ca'),
#  'born': '1912-08-30',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '1997-03-07',
#  'diedCity': 'Cambridge, MA',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'E. M.',
#  'gender': 'male',
#  'id': '59',
#  'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#                                'country': 'USA',
#                                'name': 'Harvard University'}],
#              'category': 'physics',
#              'motivation': '"for their development of new methods for nuclear '
#                            'magnetic precision measurements and discoveries in '
#                            'connection therewith"',
#              'share': '2',
#              'year': '1952'}],
#  'surname': 'Purcell'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6cb'),
#  'born': '1888-07-16',
#  'bornCountry': 'the Netherlands',
#  'bornCountryCode': 'NL',
#  'died': '1966-03-10',
#  'diedCity': 'Groningen',
#  'diedCountry': 'the Netherlands',
#  'diedCountryCode': 'NL',
#  'firstname': 'Frits',
#  'gender': 'male',
#  'id': '60',
#  'prizes': [{'affiliations': [{'city': 'Groningen',
#                                'country': 'the Netherlands',
#                                'name': 'Groningen University'}],
#              'category': 'physics',
#              'motivation': '"for his demonstration of the phase contrast '
#                            'method, especially for his invention of the phase '
#                            'contrast microscope"',
#              'share': '1',
#              'year': '1953'}],
#  'surname': 'Zernike'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6cc'),
#  'born': '1882-12-11',
#  'bornCountry': 'Germany (now Poland)',
#  'bornCountryCode': 'PL',
#  'died': '1970-01-05',
#  'diedCity': 'Göttingen',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Max',
#  'gender': 'male',
#  'id': '61',
#  'prizes': [{'affiliations': [{'city': 'Edinburgh',
#                                'country': 'United Kingdom',
#                                'name': 'Edinburgh University'}],
#              'category': 'physics',
#              'motivation': '"for his fundamental research in quantum '
#                            'mechanics, especially for his statistical '
#                            'interpretation of the wavefunction"',
#              'share': '2',
#              'year': '1954'}],
#  'surname': 'Born'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6cd'),
#  'born': '1891-01-08',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '1957-02-08',
#  'diedCity': 'Heidelberg',
#  'diedCountry': 'West Germany (now Germany)',
#  'diedCountryCode': 'DE',
#  'firstname': 'Walther',
#  'gender': 'male',
#  'id': '62',
#  'prizes': [{'affiliations': [{'city': 'Heidelberg',
#                                'country': 'Germany',
#                                'name': 'University of Heidelberg'},
#                               {'city': 'Heidelberg',
#                                'country': 'Germany',
#                                'name': 'Max-Planck-Institut für medizinische '
#                                        'Forschung'}],
#              'category': 'physics',
#              'motivation': '"for the coincidence method and his discoveries '
#                            'made therewith"',
#              'share': '2',
#              'year': '1954'}],
#  'surname': 'Bothe'}
# {'_id': ObjectId('61fd96d54039d142fbd0d6ce'),
#  'born': '1913-07-12',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '2008-05-15',
#  'diedCity': 'Tucson, AZ',
#  'diedCountry': 'USA',
#  'diedCountryCode': 'US',
#  'firstname': 'Willis E.',
#  'gender': 'male',
#  'id': '63',
#  'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#                                'country': 'USA',
#                                'name': 'Stanford University'}],
# ...
#              'motivation': '"for the discovery of Hepatitis C virus"',
#              'share': '3',
#              'year': '2020'}],
#  'surname': 'Alter'}
# {'_id': ObjectId('61fd96d54039d142fbd0da41'),
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '0000-00-00',
#  'firstname': 'Michael',
#  'gender': 'male',
#  'id': '986',
#  'prizes': [{'affiliations': [{'city': 'Edmonton',
#                                'country': 'Canada',
#                                'name': 'University of Alberta'}],
#              'category': 'medicine',
#              'motivation': '"for the discovery of Hepatitis C virus"',
#              'share': '3',
#              'year': '2020'}],
#  'surname': 'Houghton'}
# {'_id': ObjectId('61fd96d54039d142fbd0da42'),
#  'born': '1952-08-25',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Charles',
#  'gender': 'male',
#  'id': '987',
#  'prizes': [{'affiliations': [{'city': 'New York, NY',
#                                'country': 'USA',
#                                'name': 'Rockefeller University'}],
#              'category': 'medicine',
#              'motivation': '"for the discovery of Hepatitis C virus"',
#              'share': '3',
#              'year': '2020'}],
#  'surname': 'Rice'}
# {'_id': ObjectId('61fd96d54039d142fbd0da43'),
#  'born': '1931-08-08',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '0000-00-00',
#  'firstname': 'Roger',
#  'gender': 'male',
#  'id': '988',
#  'prizes': [{'affiliations': [{'city': 'Oxford',
#                                'country': 'United Kingdom',
#                                'name': 'University of Oxford'}],
#              'category': 'physics',
#              'motivation': '"for the discovery that black hole formation is a '
#                            'robust prediction of the general theory of '
#                            'relativity"',
#              'share': '2',
#              'year': '2020'}],
#  'surname': 'Penrose'}
# {'_id': ObjectId('61fd96d54039d142fbd0da44'),
#  'born': '1952-03-24',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '0000-00-00',
#  'firstname': 'Reinhard',
#  'gender': 'male',
#  'id': '989',
#  'prizes': [{'affiliations': [{'city': 'Garching',
#                                'country': 'Germany',
#                                'name': 'Max Planck Institute for '
#                                        'Extraterrestrial Physics'},
#                               {'city': 'Berkeley, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of a supermassive compact '
#                            'object at the centre of our galaxy"',
#              'share': '4',
#              'year': '2020'}],
#  'surname': 'Genzel'}
# {'_id': ObjectId('61fd96d54039d142fbd0da45'),
#  'born': '1965-06-16',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Andrea',
#  'gender': 'female',
#  'id': '990',
#  'prizes': [{'affiliations': [{'city': 'Los Angeles, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of a supermassive compact '
#                            'object at the centre of our galaxy"',
#              'share': '4',
#              'year': '2020'}],
#  'surname': 'Ghez'}
# {'_id': ObjectId('61fd96d54039d142fbd0da46'),
#  'born': '1968-12-11',
#  'bornCountry': 'France',
#  'bornCountryCode': 'FR',
#  'died': '0000-00-00',
#  'firstname': 'Emmanuelle',
#  'gender': 'female',
#  'id': '991',
#  'prizes': [{'affiliations': [{'city': 'Berlin',
#                                'country': 'Germany',
#                                'name': 'Max Planck Unit for the Science of '
#                                        'Pathogens'}],
#              'category': 'chemistry',
#              'motivation': '"for the development of a method for genome '
#                            'editing"',
#              'share': '2',
#              'year': '2020'}],
#  'surname': 'Charpentier'}
# {'_id': ObjectId('61fd96d54039d142fbd0da47'),
#  'born': '1964-02-19',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Jennifer A.',
#  'gender': 'female',
#  'id': '992',
#  'prizes': [{'affiliations': [{'city': 'Berkeley, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'chemistry',
#              'motivation': '"for the development of a method for genome '
#                            'editing"',
#              'share': '2',
#              'year': '2020'}],
#  'surname': 'Doudna'}
# {'_id': ObjectId('61fd96d54039d142fbd0da48'),
#  'born': '1943-04-22',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Louise',
#  'gender': 'female',
#  'id': '993',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for her unmistakable poetic voice that with '
#                            'austere beauty makes individual existence '
#                            'universal"',
#              'share': '1',
#              'year': '2020'}],
#  'surname': 'Glück'}
# {'_id': ObjectId('61fd96d54039d142fbd0da49'),
#  'born': '1961-00-00',
#  'died': '0000-00-00',
#  'firstname': 'World Food Programme',
#  'gender': 'org',
#  'id': '994',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for its efforts to combat hunger, for its '
#                            'contribution to bettering conditions for peace in '
#                            'conflict-affected areas and for acting as a '
#                            'driving force in efforts to prevent the use of '
#                            'hunger as a weapon of war and conflict"',
#              'share': '1',
#              'year': '2020'}]}
# {'_id': ObjectId('61fd96d54039d142fbd0da4a'),
#  'born': '1948-04-20',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Paul',
#  'gender': 'male',
#  'id': '995',
#  'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#                                'country': 'USA',
#                                'name': 'Stanford University'}],
#              'category': 'economics',
#              'motivation': '"for improvements to auction theory and inventions '
#                            'of new auction formats"',
#              'share': '2',
#              'year': '2020'}],
#  'surname': 'Milgrom'}
# {'_id': ObjectId('61fd96d54039d142fbd0da4b'),
#  'born': '1937-05-16',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Robert',
#  'gender': 'male',
#  'id': '996',
#  'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#                                'country': 'USA',
#                                'name': 'Stanford University'}],
#              'category': 'economics',
#              'motivation': '"for improvements to auction theory and inventions '
#                            'of new auction formats"',
#              'share': '2',
#              'year': '2020'}],
#  'surname': 'Wilson'}
# {'_id': ObjectId('61fd96d54039d142fbd0da4c'),
#  'born': '1955-11-04',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'David',
#  'gender': 'male',
#  'id': '997',
#  'prizes': [{'affiliations': [{'city': 'San Francisco, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries of receptors for '
#                            'temperature and touch"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'Julius'}
# {'_id': ObjectId('61fd96d54039d142fbd0da4d'),
#  'born': '1967-00-00',
#  'bornCountry': 'Lebanon',
#  'bornCountryCode': 'LB',
#  'died': '0000-00-00',
#  'firstname': 'Ardem',
#  'gender': 'male',
#  'id': '998',
#  'prizes': [{'affiliations': [{'city': 'La Jolla, CA',
#                                'country': 'USA',
#                                'name': 'Scripps Research'},
#                               {'name': 'Howard Hughes Medical Institute'}],
#              'category': 'medicine',
#              'motivation': '"for their discoveries of receptors for '
#                            'temperature and touch"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'Patapoutian'}
# {'_id': ObjectId('61fd96d54039d142fbd0da4e'),
#  'born': '1931-09-21',
#  'bornCountry': 'Japan',
#  'bornCountryCode': 'JP',
#  'died': '0000-00-00',
#  'firstname': 'Syukuro',
#  'gender': 'male',
#  'id': '999',
#  'prizes': [{'affiliations': [{'city': 'Princeton, NJ',
#                                'country': 'USA',
#                                'name': 'Princeton University'}],
#              'category': 'physics',
#              'motivation': '"for the physical modelling of Earth’s climate, '
#                            'quantifying variability and reliably predicting '
#                            'global warming"',
#              'overallMotivation': '"for groundbreaking contributions to our '
#                                   'understanding of complex physical systems"',
#              'share': '4',
#              'year': '2021'}],
#  'surname': 'Manabe'}
# {'_id': ObjectId('61fd96d54039d142fbd0da4f'),
#  'born': '1931-10-25',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '0000-00-00',
#  'firstname': 'Klaus',
#  'gender': 'male',
#  'id': '1000',
#  'prizes': [{'affiliations': [{'city': 'Hamburg',
#                                'country': 'Germany',
#                                'name': 'Max Planck Institute for Meteorology'}],
#              'category': 'physics',
#              'motivation': '"for the physical modelling of Earth’s climate, '
#                            'quantifying variability and reliably predicting '
#                            'global warming"',
#              'overallMotivation': '"for groundbreaking contributions to our '
#                                   'understanding of complex physical systems"',
#              'share': '4',
#              'year': '2021'}],
#  'surname': 'Hasselmann'}
# {'_id': ObjectId('61fd96d54039d142fbd0da50'),
#  'born': '1948-08-04',
#  'bornCountry': 'Italy',
#  'bornCountryCode': 'IT',
#  'died': '0000-00-00',
#  'firstname': 'Giorgio',
#  'gender': 'male',
#  'id': '1001',
#  'prizes': [{'affiliations': [{'city': 'Rome',
#                                'country': 'Italy',
#                                'name': 'Sapienza University of Rome'}],
#              'category': 'physics',
#              'motivation': '"for the discovery of the interplay of disorder '
#                            'and fluctuations in physical systems from atomic '
#                            'to planetary scales"',
#              'overallMotivation': '"for groundbreaking contributions to our '
#                                   'understanding of complex physical systems"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'Parisi'}
# {'_id': ObjectId('61fd96d54039d142fbd0da51'),
#  'born': '1968-01-11',
#  'bornCountry': 'Germany',
#  'bornCountryCode': 'DE',
#  'died': '0000-00-00',
#  'firstname': 'Benjamin',
#  'gender': 'male',
#  'id': '1002',
#  'prizes': [{'affiliations': [{'city': 'Mülheim an der Ruhr',
#                                'country': 'Germany',
#                                'name': 'Max-Planck-Institut für '
#                                        'Kohlenforschung'}],
#              'category': 'chemistry',
#              'motivation': '"for the development of asymmetric '
#                            'organocatalysis"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'List'}
# {'_id': ObjectId('61fd96d54039d142fbd0da52'),
#  'born': '1968-00-00',
#  'bornCountry': 'United Kingdom',
#  'bornCountryCode': 'GB',
#  'died': '0000-00-00',
#  'firstname': 'David',
#  'gender': 'male',
#  'id': '1003',
#  'prizes': [{'affiliations': [{'city': 'Princeton, NJ',
#                                'country': 'USA',
#                                'name': 'Princeton University'}],
#              'category': 'chemistry',
#              'motivation': '"for the development of asymmetric '
#                            'organocatalysis"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'MacMillan'}
# {'_id': ObjectId('61fd96d54039d142fbd0da53'),
#  'born': '1948-00-00',
#  'died': '0000-00-00',
#  'firstname': 'Abdulrazak',
#  'gender': 'male',
#  'id': '1004',
#  'prizes': [{'affiliations': [[]],
#              'category': 'literature',
#              'motivation': '"for his uncompromising and compassionate '
#                            'penetration of the effects of colonialism and the '
#                            'fate of the refugee in the gulf between cultures '
#                            'and continents"',
#              'share': '1',
#              'year': '2021'}],
#  'surname': 'Gurnah'}
# {'_id': ObjectId('61fd96d54039d142fbd0da54'),
#  'born': '1963-10-02',
#  'bornCountry': 'Philippines',
#  'bornCountryCode': 'PH',
#  'died': '0000-00-00',
#  'firstname': 'Maria',
#  'gender': 'female',
#  'id': '1005',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their efforts to safeguard freedom of '
#                            'expression, which is a precondition for democracy '
#                            'and lasting peace"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'Ressa'}
# {'_id': ObjectId('61fd96d54039d142fbd0da55'),
#  'born': '1961-00-00',
#  'bornCountry': 'USSR (now Russia)',
#  'bornCountryCode': 'RU',
#  'died': '0000-00-00',
#  'firstname': 'Dmitry',
#  'gender': 'male',
#  'id': '1006',
#  'prizes': [{'affiliations': [[]],
#              'category': 'peace',
#              'motivation': '"for their efforts to safeguard freedom of '
#                            'expression, which is a precondition for democracy '
#                            'and lasting peace"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'Muratov'}
# {'_id': ObjectId('61fd96d54039d142fbd0da56'),
#  'born': '1956-00-00',
#  'bornCountry': 'Canada',
#  'bornCountryCode': 'CA',
#  'died': '0000-00-00',
#  'firstname': 'David',
#  'gender': 'male',
#  'id': '1007',
#  'prizes': [{'affiliations': [{'city': 'Berkeley, CA',
#                                'country': 'USA',
#                                'name': 'University of California'}],
#              'category': 'economics',
#              'motivation': '"for his empirical contributions to labour '
#                            'economics"',
#              'share': '2',
#              'year': '2021'}],
#  'surname': 'Card'}
# {'_id': ObjectId('61fd96d54039d142fbd0da57'),
#  'born': '1960-00-00',
#  'bornCountry': 'USA',
#  'bornCountryCode': 'US',
#  'died': '0000-00-00',
#  'firstname': 'Joshua',
#  'gender': 'male',
#  'id': '1008',
#  'prizes': [{'affiliations': [{'city': 'Cambridge, MA',
#                                'country': 'USA',
#                                'name': 'Massachusetts Institute of Technology '
#                                        '(MIT)'}],
#              'category': 'economics',
#              'motivation': '"for their methodological contributions to the '
#                            'analysis of causal relationships"',
#              'share': '4',
#              'year': '2021'}],
#  'surname': 'Angrist'}
# {'_id': ObjectId('61fd96d54039d142fbd0da58'),
#  'born': '1963-09-03',
#  'bornCountry': 'the Netherlands',
#  'bornCountryCode': 'NL',
#  'died': '0000-00-00',
#  'firstname': 'Guido',
#  'gender': 'male',
#  'id': '1009',
#  'prizes': [{'affiliations': [{'city': 'Stanford, CA',
#                                'country': 'USA',
#                                'name': 'Stanford University'}],
#              'category': 'economics',
#              'motivation': '"for their methodological contributions to the '
#                            'analysis of causal relationships"',
#              'share': '4',
#              'year': '2021'}],
#  'surname': 'Imbens'}

# %% [markdown]
# **3- Collect Tweeter and store it in MongoDB**

# %%
# !pip install dnspython

# %%
# !pip install tweepy

# %%
# !pip install twitter

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy
import twitter
from pprint import pprint
import configparser
import pandas as pd

# %%
CONSUMER_KEY      = ""
CONSUMER_SECRET   = ""
OAUTH_TOKEN       = ""
OATH_TOKEN_SECRET = "

mongod_connect = 'mongodb://127.0.0.1:27017/'

# %%
client = MongoClient(mongod_connect)
db = client.Twitter # use or create a database named demo
tweet_collection = db.tweetData #use or create a collection named tweet_collection
# tweet_collection.create_index([("id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique

# %%
# stream_auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
# stream_auth.set_access_token(OAUTH_TOKEN, OATH_TOKEN_SECRET)

# strem_api = tweepy.API(stream_auth)

# %%
rest_auth = twitter.oauth.OAuth(OAUTH_TOKEN,OATH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
rest_api = twitter.Twitter(auth=rest_auth)

# %%
count = 100 #number of returned tweets, default and max is 100
q = "covid19"  #define the keywords, tweets contain election

# %%
search_results = rest_api.search.tweets( count=count,q=q) #you can use both q and geocode
statuses = search_results["statuses"]
since_id_new = statuses[-1]['id']
for statuse in statuses:
    try:
        tweet_collection.insert_one(statuse)
        pprint(statuse['created_at'])# print the date of the collected tweets
    except:
        pass
# Out:
# 'Mon Feb 07 14:03:57 +0000 2022'
# 'Mon Feb 07 14:03:57 +0000 2022'
# 'Mon Feb 07 14:03:57 +0000 2022'
# 'Mon Feb 07 14:03:56 +0000 2022'
# 'Mon Feb 07 14:03:55 +0000 2022'
# 'Mon Feb 07 14:03:55 +0000 2022'
# 'Mon Feb 07 14:03:55 +0000 2022'
# 'Mon Feb 07 14:03:54 +0000 2022'
# 'Mon Feb 07 14:03:53 +0000 2022'
# 'Mon Feb 07 14:03:52 +0000 2022'
# 'Mon Feb 07 14:03:52 +0000 2022'
# 'Mon Feb 07 14:03:52 +0000 2022'
# 'Mon Feb 07 14:03:52 +0000 2022'
# 'Mon Feb 07 14:03:51 +0000 2022'
# 'Mon Feb 07 14:03:51 +0000 2022'
# 'Mon Feb 07 14:03:51 +0000 2022'
# 'Mon Feb 07 14:03:51 +0000 2022'
# 'Mon Feb 07 14:03:49 +0000 2022'
# 'Mon Feb 07 14:03:49 +0000 2022'
# 'Mon Feb 07 14:03:48 +0000 2022'
# 'Mon Feb 07 14:03:48 +0000 2022'
# 'Mon Feb 07 14:03:48 +0000 2022'
# 'Mon Feb 07 14:03:48 +0000 2022'
# 'Mon Feb 07 14:03:48 +0000 2022'
# 'Mon Feb 07 14:03:47 +0000 2022'
# 'Mon Feb 07 14:03:46 +0000 2022'
# 'Mon Feb 07 14:03:46 +0000 2022'
# 'Mon Feb 07 14:03:46 +0000 2022'
# 'Mon Feb 07 14:03:46 +0000 2022'
# 'Mon Feb 07 14:03:45 +0000 2022'
# 'Mon Feb 07 14:03:45 +0000 2022'
# 'Mon Feb 07 14:03:45 +0000 2022'
# 'Mon Feb 07 14:03:45 +0000 2022'
# 'Mon Feb 07 14:03:45 +0000 2022'
# 'Mon Feb 07 14:03:45 +0000 2022'
# 'Mon Feb 07 14:03:44 +0000 2022'
# 'Mon Feb 07 14:03:44 +0000 2022'
# 'Mon Feb 07 14:03:44 +0000 2022'
# 'Mon Feb 07 14:03:44 +0000 2022'
# 'Mon Feb 07 14:03:43 +0000 2022'
# 'Mon Feb 07 14:03:42 +0000 2022'
# 'Mon Feb 07 14:03:42 +0000 2022'
# 'Mon Feb 07 14:03:42 +0000 2022'
# 'Mon Feb 07 14:03:42 +0000 2022'
# 'Mon Feb 07 14:03:42 +0000 2022'
# 'Mon Feb 07 14:03:40 +0000 2022'
# 'Mon Feb 07 14:03:38 +0000 2022'
# 'Mon Feb 07 14:03:38 +0000 2022'
# 'Mon Feb 07 14:03:37 +0000 2022'
# 'Mon Feb 07 14:03:37 +0000 2022'
# 'Mon Feb 07 14:03:36 +0000 2022'
# 'Mon Feb 07 14:03:36 +0000 2022'
# 'Mon Feb 07 14:03:36 +0000 2022'
# 'Mon Feb 07 14:03:36 +0000 2022'
# 'Mon Feb 07 14:03:34 +0000 2022'
# 'Mon Feb 07 14:03:34 +0000 2022'
# 'Mon Feb 07 14:03:33 +0000 2022'
# 'Mon Feb 07 14:03:33 +0000 2022'
# 'Mon Feb 07 14:03:32 +0000 2022'
# 'Mon Feb 07 14:03:32 +0000 2022'
# 'Mon Feb 07 14:03:32 +0000 2022'
# 'Mon Feb 07 14:03:32 +0000 2022'
# 'Mon Feb 07 14:03:32 +0000 2022'
# 'Mon Feb 07 14:03:31 +0000 2022'
# 'Mon Feb 07 14:03:31 +0000 2022'
# 'Mon Feb 07 14:03:30 +0000 2022'
# 'Mon Feb 07 14:03:30 +0000 2022'
# 'Mon Feb 07 14:03:28 +0000 2022'
# 'Mon Feb 07 14:03:28 +0000 2022'
# 'Mon Feb 07 14:03:28 +0000 2022'
# 'Mon Feb 07 14:03:28 +0000 2022'
# 'Mon Feb 07 14:03:27 +0000 2022'
# 'Mon Feb 07 14:03:27 +0000 2022'
# 'Mon Feb 07 14:03:27 +0000 2022'
# 'Mon Feb 07 14:03:27 +0000 2022'
# 'Mon Feb 07 14:03:27 +0000 2022'
# 'Mon Feb 07 14:03:27 +0000 2022'
# 'Mon Feb 07 14:03:26 +0000 2022'
# 'Mon Feb 07 14:03:25 +0000 2022'
# 'Mon Feb 07 14:03:25 +0000 2022'
# 'Mon Feb 07 14:03:25 +0000 2022'
# 'Mon Feb 07 14:03:24 +0000 2022'
# 'Mon Feb 07 14:03:23 +0000 2022'
# 'Mon Feb 07 14:03:23 +0000 2022'
# 'Mon Feb 07 14:03:23 +0000 2022'
# 'Mon Feb 07 14:03:23 +0000 2022'
# 'Mon Feb 07 14:03:23 +0000 2022'
# 'Mon Feb 07 14:03:22 +0000 2022'
# 'Mon Feb 07 14:03:21 +0000 2022'
# 'Mon Feb 07 14:03:21 +0000 2022'
# 'Mon Feb 07 14:03:20 +0000 2022'
# 'Mon Feb 07 14:03:19 +0000 2022'
# 'Mon Feb 07 14:03:19 +0000 2022'
# 'Mon Feb 07 14:03:18 +0000 2022'
# 'Mon Feb 07 14:03:17 +0000 2022'
# 'Mon Feb 07 14:03:16 +0000 2022'
# 'Mon Feb 07 14:03:16 +0000 2022'
# 'Mon Feb 07 14:03:16 +0000 2022'
# 'Mon Feb 07 14:03:16 +0000 2022'
# 'Mon Feb 07 14:03:16 +0000 2022'

# %%
print(tweet_collection.estimated_document_count())# number of tweets collected
# Out:
# 100

# %%
tweet_collection.create_index([("text", pymongo.TEXT)], name='text_index', default_language='english') # create a text index
# Out:
# 'text_index'
